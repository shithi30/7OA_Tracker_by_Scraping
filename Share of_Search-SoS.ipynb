# %%
## Chaldal SoS

# import
import pandas as pd
import duckdb
from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from googleapiclient.discovery import build
from google.oauth2 import service_account
import time

# accumulators
start_time = time.time()
df_acc = pd.DataFrame()

# particulars
keywords = ['conditioner', 'handwash', 'bodywash', 'facewash', 'lotion', 'cream', 'toothpaste', 'dishwash', 'toilet clean', 'soup', 'shampoo', 'health drink', 'washing powder', 'wash liquid', 'detergent', 'moisturizer', 'soap', 'petroleum jelly', 'hair oil', 'germ kill']
brands = ['Boost Health', 'Boost Drink', 'Boost Jar', 'Clear Shampoo', 'Simple Fac', 'Simple Mask', 'Pepsodent', 'Brylcreem', 'Bru Coffee', 'St. Ives', 'St.Ives', 'Horlicks', 'Sunsilk', 'Sun Silk', 'Lux', 'Ponds', "Pond's", 'Closeup', 'Close Up', 'Cif', 'Dove', 'Maltova', 'Domex', 'Clinic Plus', 'Tresemme', 'Tresemmé', 'GlucoMax', 'Knorr', 'Glow Lovely', 'Fair Lovely', 'Glow Handsome', 'Wheel Wash', 'Axe Body', 'Pureit', 'Lifebuoy', 'Surf Excel', 'Vaseline', 'Vim', 'Rin']
    
# subsequence
def is_subseq(x, y):
    it = iter(y)
    return all(any(c == ch for c in it) for ch in x)
    
# preference
options = webdriver.ChromeOptions()
options.add_argument('ignore-certificate-errors')

# open window
driver = webdriver.Chrome(options=options)
driver.maximize_window()

# url
for k in keywords:
    print("Scraping for keyword: " + k)
    url = "https://chaldal.com/search/" + k
    driver.get(url)

    # scroll
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(5)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height: break
        last_height = new_height

    # soup
    soup_init = BeautifulSoup(driver.page_source, 'html.parser')
    soup = soup_init.find_all("div", attrs={"class": "product"})

    # scrape
    skus = []
    quants = []
    prices = []
    prices_if_discounted = []
    options = []
    if_ubl = [] 
    for s in soup:
        # sku
        try: val = s.find("div", attrs={"class": "name"}).get_text()
        except: val = None
        skus.append(val)
        # quantity
        try: val = s.find("div", attrs={"class": "subText"}).get_text()
        except: val = None
        quants.append(val)
        # price
        try: val = float(s.find("div", attrs={"class": "price"}).get_text().split()[1].replace(',', ''))
        except: val = None
        prices.append(val)
        # discount
        try: val = float(s.find("div", attrs={"class": "discountedPrice"}).get_text().split()[1].replace(',', ''))
        except: val = None
        prices_if_discounted.append(val)
        # option
        try: val = s.find("p", attrs={"class": "buyText"}).get_text() 
        except: val = None
        options.append(val)

    # accumulate
    df = pd.DataFrame()
    df['sku'] = [str(s) + ' ' + str(q) for s, q in zip(skus, quants)]
    df['quantity'] = quants
    df['price'] = prices
    df['price_if_discounted'] = prices_if_discounted
    df['option'] = options
    df['pos_in_pg'] = list(range(1, df.shape[0]+1))
    df['keyword'] = k
    df['relevance'] = ['relevant' if is_subseq(k.replace(' ', ''), s.lower()) else 'irrelevant' for s in skus]
    # Unilever
    sku_count = len(skus)
    for i in range(0, sku_count):
        if_ubl.append(None)
        for b in brands:
            bb = b.split()
            if len(bb) == 1: bb.append('')
            if bb[0].lower() + ' ' in skus[i].lower() and bb[1].lower() in skus[i].lower(): if_ubl[i] = b
    df['brand_unilever'] = if_ubl

    # record
    df['report_time'] = time.strftime('%d-%b-%y, %I:%M %p')
    df_acc = df_acc._append(df).fillna('')

# close window
driver.close()

# SoS
qry = '''
select
    keyword, 
    count(1) results, 
    count(case when relevance='relevant' then 1 else null end) relevant_results, 
    count(case when relevance='relevant' and brand_unilever!='' then 1 else null end) relevant_results_ubl,
    round(count(case when relevance='relevant' and brand_unilever!='' then 1 else null end)*1.00/count(case when relevance='relevant' then 1 else null end), 4) ubl_sos, 
    count(case when relevance='relevant' and brand_unilever!='' and pos_in_pg<11 then 1 else null end) ubl_sos_top10,
    max(report_time) report_time
from df_acc
group by 1
'''
sos_df = duckdb.query(qry).df().fillna('')

# credentials
SERVICE_ACCOUNT_FILE = 'read-write-to-gsheet-apis-1-04f16c652b1e.json'
SAMPLE_SPREADSHEET_ID = '1gkLRp59RyRw4UFds0-nNQhhWOaS4VFxtJ_Hgwg2x2A0'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

# API
creds = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
service = build('sheets', 'v4', credentials=creds)
sheet = service.spreadsheets()

# update
sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID, range='Chaldal SoS').execute()
sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Chaldal SoS!A1", valueInputOption='USER_ENTERED', body={'values': [df_acc.columns.values.tolist()] + df_acc.values.tolist()}).execute()
sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Chaldal SoS!L1", valueInputOption='USER_ENTERED', body={'values': [sos_df.columns.values.tolist()] + sos_df.values.tolist()}).execute()

# stats
# display(df_acc.head(5))
print("Listings in result: " + str(df_acc.shape[0]))
elapsed_time = time.time() - start_time
print("Elapsed time to report (mins): " + str(round(elapsed_time / 60.00, 2)))
# Out:
# Scraping for keyword: conditioner
# Scraping for keyword: handwash
# Scraping for keyword: bodywash
# Scraping for keyword: facewash
# Scraping for keyword: lotion
# Scraping for keyword: cream
# Scraping for keyword: toothpaste
# Scraping for keyword: dishwash
# Scraping for keyword: toilet clean
# Scraping for keyword: soup
# Scraping for keyword: shampoo
# Scraping for keyword: health drink
# Scraping for keyword: washing powder
# Scraping for keyword: wash liquid
# Scraping for keyword: detergent
# Scraping for keyword: moisturizer
# Scraping for keyword: soap
# Scraping for keyword: petroleum jelly
# Scraping for keyword: hair oil
# Scraping for keyword: germ kill
# Listings in result: 2203
# Elapsed time to report (mins): 7.4

# %%
# Pandamart SoS

# import
import pandas as pd
import duckdb
from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from googleapiclient.discovery import build
from google.oauth2 import service_account
import time

# accumulators
start_time = time.time()
df_acc = pd.DataFrame()

# particulars
keywords = ['conditioner', 'handwash', 'bodywash', 'facewash', 'lotion', 'face cream', 'toothpaste', 'dishwash', 'toilet clean', 'soup', 'shampoo', 'health drink', 'detergent', 'moisturizer', 'soap', 'petroleum jelly', 'hair oil', 'germ kill']
brands = ['Boost Health', 'Boost Drink', 'Boost Jar', 'Clear Shampoo', 'Simple Fac', 'Simple Mask', 'Pepsodent', 'Brylcreem', 'Bru Coffee', 'St. Ives', 'St.Ives', 'Horlicks', 'Sunsilk', 'Sun Silk', 'Lux', 'Ponds', "Pond's", 'Closeup', 'Close Up', 'Cif', 'Dove', 'Maltova', 'Domex', 'Clinic Plus', 'Tresemme', 'Tresemmé', 'GlucoMax', 'Knorr', 'Glow Lovely', 'Fair Lovely', 'Glow Handsome', 'Wheel Wash', 'Axe Body', 'Pureit', 'Lifebuoy', 'Surf Excel', 'Vaseline', 'Vim', 'Rin']

# preference
options = webdriver.ChromeOptions()
options.add_argument('ignore-certificate-errors')

# open window
driver = webdriver.Chrome(options=options)
driver.maximize_window()
driver.get("https://www.foodpanda.com.bd/darkstore/w2lx/pandamart-gulshan-w2lx")

# keyword
for k in keywords:
    print("Scraping for keyword: " + k)
    elem = driver.find_element(By.XPATH, '//*[@id="groceries-menu-react-root"]/div/div/div[2]/div/section/div[3]/div/div/div/div/div[1]/input')
    elem.send_keys(k + "\n")

    # scroll
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        time.sleep(5)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height: break
        last_height = new_height
    
    # soup
    soup_init = BeautifulSoup(driver.page_source, 'html.parser')
    soup = soup_init.find_all('div', attrs={'class', 'box-flex product-card-attributes'})

    # scrape
    sku = []
    current_price = []
    original_price = []
    offer = []
    if_ubl = [] 
    for s in soup:
        # sku
        try: val = s.find('p', attrs={'class', 'product-card-name'}).get_text()
        except: val = None
        sku.append(val)
        # current price
        try: val = s.find("span", attrs={"data-testid", "product-card-price"}).get_text().split()[1]
        except: val = None
        current_price.append(val)
        # original price
        try: val = s.find("span", attrs={"data-testid", "product-card-price-before-discount"}).get_text().split()[1]
        except: val = None
        original_price.append(val)
        # offer
        try: val = s.find("span", attrs={"class", "bds-c-tag__label"}).get_text()
        except: val = None
        offer.append(val)

    # accumulate
    df = pd.DataFrame()
    df['sku'] = sku
    df['current_price'] = current_price
    df['original_price'] = original_price
    df['offer'] = offer
    df['pos_in_pg'] = list(range(1, df.shape[0]+1))
    df['keyword'] = k
  
    # Unilever
    sku_count = len(sku)
    for i in range(0, sku_count):
        if_ubl.append(None)
        for b in brands:
            bb = b.split()
            if len(bb) == 1: bb.append('')
            if bb[0].lower() + ' ' in sku[i].lower() and bb[1].lower() in sku[i].lower(): if_ubl[i] = b
    df['brand_unilever'] = if_ubl

    # record
    df['report_time'] = time.strftime('%d-%b-%y, %I:%M %p')
    df_acc = df_acc._append(df).fillna('')
    
    # back
    driver.back()

# close window
driver.close()

# SoS
qry = '''
select
    keyword, 
    count(1) results, 
    count(case when brand_unilever!='' then 1 else null end) results_ubl,
    round(count(case when brand_unilever!='' then 1 else null end)*1.00/count(1), 4) ubl_sos,
    count(case when brand_unilever!='' and pos_in_pg<11 then 1 else null end) ubl_sos_top10,
    max(report_time) report_time
from df_acc
group by 1
'''
sos_df = duckdb.query(qry).df().fillna('')

# credentials
SERVICE_ACCOUNT_FILE = 'read-write-to-gsheet-apis-1-04f16c652b1e.json'
SAMPLE_SPREADSHEET_ID = '1gkLRp59RyRw4UFds0-nNQhhWOaS4VFxtJ_Hgwg2x2A0'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

# API
creds = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
service = build('sheets', 'v4', credentials=creds)
sheet = service.spreadsheets()

# update
sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID, range='Pandamart SoS').execute()
sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Pandamart SoS!A1", valueInputOption='USER_ENTERED', body={'values': [df_acc.columns.values.tolist()] + df_acc.values.tolist()}).execute()
sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Pandamart SoS!J1", valueInputOption='USER_ENTERED', body={'values': [sos_df.columns.values.tolist()] + sos_df.values.tolist()}).execute()

# stats
# display(df_acc.head(5))
print("Listings in result: " + str(df_acc.shape[0]))
elapsed_time = time.time() - start_time
print("Elapsed time to report (mins): " + str(round(elapsed_time / 60.00, 2)))
# Out:
# Scraping for keyword: conditioner
# Scraping for keyword: handwash
# Scraping for keyword: bodywash
# Scraping for keyword: facewash
# Scraping for keyword: lotion
# Scraping for keyword: face cream
# Scraping for keyword: toothpaste
# Scraping for keyword: dishwash
# Scraping for keyword: toilet clean
# Scraping for keyword: soup
# Scraping for keyword: shampoo
# Scraping for keyword: health drink
# Scraping for keyword: detergent
# Scraping for keyword: moisturizer
# Scraping for keyword: soap
# Scraping for keyword: petroleum jelly
# Scraping for keyword: hair oil
# Scraping for keyword: germ kill
# Listings in result: 1366
# Elapsed time to report (mins): 8.05

# %%
## Shajgoj SoS

# import
import pandas as pd
import duckdb
from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from googleapiclient.discovery import build
from google.oauth2 import service_account
import time

# accumulators
start_time = time.time()
df_acc = pd.DataFrame()

# subsequence
def is_subseq(x, y):
    it = iter(y)
    return all(any(c == ch for c in it) for ch in x)

# particulars
keywords = ['conditioner', 'handwash', 'bodywash', 'facewash', 'lotion', 'cream', 'toothpaste', 'shampoo', 'moisturizer', 'soap', 'petroleumjelly', 'hairoil']
brands = ['Clear Shampoo', 'Simple Fac', 'Simple Mask', 'Pepsodent', 'Brylcreem', 'St. Ives', 'St.Ives', 'Sunsilk', 'Sun Silk', 'Lux', 'Ponds', "Pond's", 'Closeup', 'Close Up', 'Cif', 'Dove', 'Clinic Plus', 'Tresemme', 'Tresemmé', 'Glow Lovely', 'Fair Lovely', 'Glow Handsome', 'Axe Body', 'Lifebuoy', 'Vaseline']

# preference
options = webdriver.ChromeOptions()
options.add_argument('ignore-certificate-errors')

# open window
driver = webdriver.Chrome(options=options)
driver.maximize_window()

# keyword
for k in keywords:
    print("Scraping for keyword: " + k)
    i = 0
    skus = []
    
    # url
    while(1):
        driver.get("https://shop.shajgoj.com/shop/#q=" + k + "&hPP=21&idx=wp_posts_product&p=" + str(i) + "&post_type=product&is_v=1")
        i = i + 1
        time.sleep(3)
        
        # initialize
        relevance = 'irrelevant'
        soup_init = BeautifulSoup(driver.page_source, 'html.parser').find_all("div", attrs={"class": "ais-infinite-hits--item ais-hits--item"})
        skus_init = len(skus)

        # soup
        for s in soup_init: 
            sku = s.find("a", attrs={"class": "product_title"}).get_text()
            if sku not in skus: skus.append(sku)
        for s in skus[skus_init:]:
            if is_subseq(k.replace(' ', ''), s.lower()): 
                print(s)
                relevance = 'relevant'
        if relevance == 'irrelevant' or skus_init > 250: break
        soup = soup_init

    # scrape
    skus = []
    quants = []
    prices = []
    prices_app = []
    prices_before = []
    offers = []
    options = []
    ratings = []
    if_ubl = []
    for s in soup:

        # sku
        try: val = s.find("a", attrs={"class": "product_title"}).get_text()
        except: val = None
        skus.append(val)

        # quantity
        try: val = s.find("div", attrs={"class": "alg-variation"}).get_text().strip()
        except: val = None
        quants.append(val)

        # price
        try: val = s.find("span", attrs={"class": "alg-hit__currentprice product_price"}).get_text().strip().split()[1]
        except: val = None
        prices.append(val)

        # app price
        try: val = s.find("div", attrs={"class": "alg-app-price"}).get_text().split()[-1]
        except: val = None
        prices_app.append(val)

        # price before
        try: val = s.find("span", attrs={"class": "alg-hit__previousprice product_price"}).get_text().strip().split()[1]
        except: val = None
        prices_before.append(val)

        # offer
        try: val = s.find("div", attrs={"class": "alg-product-ribbon-container"}).get_text().strip()
        except: val = None
        offers.append(val)

        # option
        try: val = s.find("div", attrs={"class": "alg-hit__actions"}).get_text().strip()
        except: val = None
        options.append(val)

        # rating
        try: val = float(s.find("span", attrs={"class": "alg-rating"})["style"][6:-2])/20
        except: val = None
        ratings.append(val)

    # accumulate
    df = pd.DataFrame()
    df['basepack'] = skus
    df['sku'] = [s + ' ' + q for s, q in zip(skus, quants)]
    df['quantity'] = quants
    df['price'] = prices
    df['price_app'] = prices_app
    df['price_before'] = prices_before
    df['offer'] = offers
    df['option'] = options
    df['rating'] = ratings
    df['keyword'] = k
    df['relevance'] = ['relevant' if is_subseq(k.replace(' ', ''), s.lower()) else 'irrelevant' for s in skus]

    # Unilever
    sku_count = len(skus)
    for i in range(0, sku_count):
        if_ubl.append(None)
        for b in brands:
            bb = b.split()
            if len(bb) == 1: bb.append('')
            if bb[0].lower() + ' ' in skus[i].lower() and bb[1].lower() in skus[i].lower(): if_ubl[i] = b
    df['brand_unilever'] = if_ubl

    # record
    df = duckdb.query('''select distinct * from df''').df()
    df['pos_in_pg'] = list(range(1, df.shape[0]+1))
    df['report_time'] = time.strftime('%d-%b-%y, %I:%M %p')
    df_acc = df_acc._append(df).fillna('')
    
# close window
driver.close()

# SoS
qry = '''
select
    keyword, 
    count(1) results, 
    count(case when relevance='relevant' then 1 else null end) relevant_results, 
    count(case when relevance='relevant' and brand_unilever!='' then 1 else null end) relevant_results_ubl,
    round(count(case when relevance='relevant' and brand_unilever!='' then 1 else null end)*1.00/count(case when relevance='relevant' then 1 else null end), 4) ubl_sos, 
    count(case when relevance='relevant' and brand_unilever!='' and pos_in_pg<11 then 1 else null end) ubl_sos_top10,
    max(report_time) report_time
from df_acc
group by 1
'''
sos_df = duckdb.query(qry).df().fillna('')

# credentials
SERVICE_ACCOUNT_FILE = 'read-write-to-gsheet-apis-1-04f16c652b1e.json'
SAMPLE_SPREADSHEET_ID = '1gkLRp59RyRw4UFds0-nNQhhWOaS4VFxtJ_Hgwg2x2A0'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

# APIs
creds = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
service = build('sheets', 'v4', credentials=creds)
sheet = service.spreadsheets()

# update
sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID, range='Shajgoj SoS').execute()
sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Shajgoj SoS!A1", valueInputOption='USER_ENTERED', body={'values': [df_acc.columns.values.tolist()] + df_acc.values.tolist()}).execute()
sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Shajgoj SoS!P1", valueInputOption='USER_ENTERED', body={'values': [sos_df.columns.values.tolist()] + sos_df.values.tolist()}).execute()

# stats
# display(df_acc.head(5))
print("Total SKUs found: " + str(df_acc.shape[0]))
elapsed_time = time.time() - start_time
print("Elapsed time to report (mins): " + str(round(elapsed_time / 60.00, 2)))
# Out:
# Scraping for keyword: conditioner
# Skin Cafe Hair Care BOGO Offer 2 ( Skin Cafe Biotin Shampoo with Onion Extract + Skin Cafe Silky Tresses Moisturizing Conditioner )
# Skin Cafe Hair Care BOGO Offer 1 ( Skin Cafe Banana Shampoo with Egg Protein + Skin Cafe Silky Tresses Moisturizing Conditioner )
# Skin Cafe Silky Tresses Moisturizing Conditioner
# Matrix Opti Care Smooth Straight Professional Conditioner
# Dove Conditioner Hairfall Rescue
# Dove Split Ends Rescue Conditioner
# Tresemme Keratin Smooth Colour With Moroccan Oil Conditioner
# Pantene Active Pro-V Smooth & Sleek 3-In-1 Shampoo + Conditioner + Treatment
# Dove Moisturizing Hydratant Conditioner
# LIL'AFIX Keratin Complex Hair Care Conditioner
# Herbal Essences Daily Detox Shine White Tea & Mint Conditioner
# TRESemmé Moisture Rich Conditioner
# Buy 1 Freyias Damage Repair Shampoo with Coconut Milk 220ml & Get 1 Freyias Moisture Sealing Hair Conditioner 100ml Free
# L’Oréal Paris Elvive Hyaluron Conditioner 360ml
# L'Oreal Paris Total Repair 5 Conditioner
# Freyias Moisture Sealing Hair Conditioner
# Wow Skin Science Hair Loss Control Therapy Conditioner
# Wow Skin Science Apple Cider Vinegar Conditioner
# Ogx Fight Fallout + Niacin3 & Caffeine Conditioner
# Haay Recover Deep Conditioner
# L'Oreal Elvive Full Restore 5 Damaged Hair Conditioner
# Sunsilk Smooth & Manageable Active-Infusion Serum Conditioner
# L´Oreal Paris Elvive Colour Protect Conditioner
# Finesse Restore + Strengthen Moisturizing & Shine Enhancing 2 in 1 Shampoo Plus Conditioner with Camellia Oil
# Herbal Essences Blue Ginger Conditioner
# LIL'AFIX Professional Conditioner Spray - Blue
# Herbal Essences White Strawberry & Sweet Mint CONDITIONER- For Cleansing and Volume No Paraben No Colorants
# Sunsilk Lively Clean & Fresh Conditioner
# Dove Nourishing Oil Care Conditioner
# LIL'AFIX Professional Conditioner Spray - Pink
# Head & Shoulders 2-in-1 Smooth and Silky Anti Dandruff Shampoo + Conditioner for Women & Men
# Pantene Pro V Anti Hair Fall Oil Replacement Leave In Conditioner
# Yusera Detangler Shine & Soft Shampoo With Conditioner
# Tresemme ANTI-BREAKAGE CONDITIONER FOR DAMAGED HAIR
# TRESemme Conditioner Smooth & Silky Conditioner
# XHC Xpel Hair Care Strawberry Conditioner
# Buy Yusera Detangler Shine & Soft Shampoo With Conditioner  500 ml Get Yusera Detangler Shine & Soft Shampoo With Conditioner 300 ml
# TRESemmé 24 Hour Volumizing Conditioner for Fine Hair
# Buy 1 Freyias Hair Fall Control Shampoo with Onion Oil 220ml & Get 1 Freyias Moisture Sealing Hair Conditioner 100ml Free
# Embla Professional Conditioner
# Pierre Cardin 2 In 1 Shampoo & Conditioner
# Pantene Advanced Hairfall Solution 2in1 Anti-Hairfall Shampoo & Conditioner for Women
# Suave Kids 3 in 1 Shampoo, Conditioner, Body Wash With Shea Butter
# ProVoke Touch Of Silver Leave-In Conditioner
# Xpel Hemp Conditioner
# Tresemme Botanique Nourish & Replenish Conditioner
# Herbal Essences Bee Strong Conditioner
# XHC Xpel Hair Care Green Tea Conditioner
# Dove Intense Repair Conditioner
# Sunsilk Hair Fall Solution Conditioner
# Mielle Rosemary Mint Strengthening Leave-In Conditioner
# Mielle Pomegranate & Honey Leave-In Conditioner
# Suave Kids Smoothing Strawberry Blast 2-in-1 Shampoo and Conditioner
# Mielle Babassu Oil & Mint Deep Conditioner
# Tresemme Conditioner Keratin Smooth 190ml
# Dove Conditioner Intense Repair
# TRESemmé Keratin Smooth Conditioner 700 ml
# Streax Professional Canvo Line Conditioner For Keratin Treated And Straightened Hair
# Dove Daily care Conditioner
# TRESemmé 24 Hour Volume Conditioner
# Tresemme Rich Moisture + Hyaluronic Plex 7X Conditioner 828ml
# Head & Shoulders 2-in-1 Cool Menthol Anti Dandruff Shampoo + Conditioner for Women & Men
# Pantene Advanced Hairfall Solution Anti-Hairfall Silky Smooth Conditioner
# TRESemme Anti-Breakage Defense Conditioner
# Suave Kids Silly Apple Wonder 3 In 1 Shampoo + Conditioner + Body Wash
# Buy Dove Shampoo Hairfall Rescue 340ml (Get Intense Repair Conditioner 50 ml Free)
# WOW Skin Science Moroccan Argan Oil Shampoo 300ml and WOW Skin Science Moroccan Argan Oil Conditioner 300ml Combo
# WOW Skin Science Red Onion Black Seed Oil Shampoo 300ml and WOW Skin Science Onion Red Seed Oil Conditioner 300ml Combo
# Tresemme Keratin Smooth Conditioner (Expiry Date 1/6/2024)
# Herbal Essences Daily Detox Clean Conditioner - 400ml
# Pantene Pro-V Classic Clean Hair Conditioner
# Revlon Flex Extra Body Conditioner With Panthenol
# Sunslik Smooth & Manageable hair Conditioner
# Palmer's Olive Oil Shine Therapy Leave-In Conditioner
# Dove Intensive Repair Conditioner For Damaged Hair
# GK Hair Color Protection Moisturizing Conditioner
# TRESemmé Pro Collection Biotin + Repair 7 Conditioner
# Farmasi Naturelle Olive Oil Hair Conditioner
# XHC Tea Tree Moisturizing Conditioner
# OGX Coconut Milk Conditioner
# Herbal Essence Arabica Coffee Fruit Conditioner
# Herbal Essences Ignite My Colour Conditioner
# Tresemme Keretin Smooth Conditioner (Thailand)
# Pantene Advanced Hairfall Solution Anti-Hairfall Conditioner for Women
# Herbal Essences Repair Argan Oil Of Morocco Conditioner
# Herbal Essences Love Me Longer Conditioner
# Tresemme Cleanse & Replenish 3 in 1 Shampoo Conditioner & Detangler
# TRESemmé Revitalize Color Conditioner for Color Treated Hair
# Buy Dove Shampoo Intense Repair 340ml (Get Intense Repair Conditioner 50 ml Free)
# Pantene Advanced Hairfall Solution 2in1 Anti-Hairfall  Silky Smooth Shampoo & Conditioner for Women
# Pantene Advanced Hairfall Solution Anti-Hairfall Total Damage Care Conditioner for Women
# OGX Argan Oil of Morocco Conditioner
# OGX Brazilian Keratin Smooth Conditioner
# Herbal Essences Conditioner Dazzle Shine
# OGX Biotin & Collagen Conditioner
# Guerniss Strong Core & Empower Conditioner
# Herbal Essences coconut Milk Conditioner 400 ml
# Wow Skin Science Coconut & Avocado Conditioner
# Tresemme Split Recovery Brazil Nut Oil & Reconstructing Complex Conditioner
# TRESemmé Flawless Curls Conditioner with Coconut Oil
# Mamaearth Apple cider vineger Conditioner
# Buy Tresemme Shampoo Color Revitalise 580ml Get Tresemme Conditioner 190ml Free
# Buy Tresemme Shampoo Keratin Smooth 580ml Get Tresemme Conditioner 190ml Free
# OGX Weightless Hydration + Coconut Water Conditioner
# Boots Fresh Coconut & Almond Conditioner
# Mamaearth Onion Conditioner for Hair Fall Control
# Baali Herbal Dandruff Care Shampoo With Conditioner Aloe Vera Tulsi Neem
# Tresemme Keratin Smooth Condoitioner with Argan Oil ( Indonesia )
# Follow Me Mild & Gentle Egg Shampoo with Conditioner
# Streax Professional Argan Secrets Colour Protect Conditioner
# Head And Shoulders 2in1 Smooth & Silky Shampoo and Conditioner
# Head And Shoulders 2in1 Apple Fresh Shampoo and Conditioner
# Herbal Essences Hello Hydration Moisturizing Conditioner
# Buy Dove Shampoo Nourishing Oil Care 330ml (Get Intense Repair Conditioner 50 ml Free)
# Dove Shampoo Oxygen Moisture 330ml (Conditioner Free)
# Gelatti Spiderman 3 in 1 Shampoo Conditioner Shower Gel
# Creightons Argan Smooth Moisture Rich Conditioner
# Herbal Essences Coconut Milk CONDITIONER- For Hydration- No Paraben No Colorants No Gluten
# Dove Hair Conditioner Straight & Silky
# Dove Hair Conditioner Hair Fall Rescue
# Love Beauty and  Planet Conditioner Neroil Oil & White Jasmine
# Biotique Bio Green Apple Shampoo & Conditioner
# Herbal Essences BioRenew Lightweight Shine Cucumber & Green Tea Conditioner  ( Thailand )
# L’Oreal Elvive Extraordinary Clay Rebalancing Hair Conditioner
# Head & Shoulders 2-in-1 Active Protect,  Anti Dandruff Shampoo + Conditioner for Women & Men
# Pantene Advanced Hairfall Solution, Anti-Hairfall Silky Smooth Conditioner
# Pantene Advanced Hairfall Solution, Anti-Hairfall Conditioner for Women
# By My Beard Conditioner And Face Moisturiser
# The Tresemme Luxurious Moisture Rich Conditioner
# Tresemme Expert Botanique Nourish and Replenish Conditioner
# Bigen Hair Color Conditioner Natural Black 881
# OGX Fade-Defying+ Orchid Oil pH Balanced Conditioner
# OGX Hydrating Macadamia Oil Conditioner
# Kumano Cosmetics C-Shikioriori Camelia Oil Conditioner
# Herbal Essences Uplifting Volume Conditioner
# Dove Men Shampoo+Conditioner Invigoration Ignite Shampoo
# Xpel Hair Care Revitalising Coconut Water Conditioner
# Herbal Essences Bee Strong Conditioner 680 Ml
# L'OREAL PARIS Elvive Extraordinary Oil Weightless Nourishing Conditioner
# XHC Xpel Banana Conditioner
# OGX Vanilla & Chai Spice Conditioner
# XHC Keratin Classic Conditioner
# Herbal Essences Conditioner Naked Daily Clean
# TRESemmé Anti-Sponge Conditioner
# OGX Tea Tree Mint Conditioner
# TRESemmé 24 Hour Body Volume Conditioner
# Dove Conditioner Oxygen Moisture
# Tresemme Botanique Damage Recovery Conditioner
# Scraping for keyword: handwash
# Mediker SafeLife Hand Wash Refill Combo Pack with Neem & Olive Oil | Protection from Germs | Fights Bacteria, Virus, Fungi | (170ml X 2pcs)
# Buy pack of 4 Godrej Magic Lime Aloe Vera Handwash Refill 9 gm Get 20 Tk Off (makes 800ml of Handwash)
# Earth Beauty & You Purifying Plum Hand Wash
# Earth Beauty & You Purifying Cherry Hand Wash
# Akij Daily Hand Wash Lavender
# Akij Daily Hand Wash Ocean
# Savlon Handwash Aloe Vera 170ml Pouch
# Savlon Handwash Ocean Blue 200ml Pump
# Lifebuoy Handwash (Soap) Total Refill 170ml
# Savlon Handwash Lemon Burst  200ml Pump
# Savlon Handwash Aloe Vera 200ml Pump
# Lifebuoy Handwash (Soap) Total Pump 200ml
# Organikare Lemon Hand Wash
# Lifebuoy Handwash (Soap) Care Refill 170ml (Combo Pack)
# Organikare Lavender Hand Wash
# Lifebuoy Handwash (Soap) Lemon Fresh Pump
# Akij Daily Hand Wash Lavender (Refill)
# Dettol Handwash Cool Ph Balanced Liquid Soap Refill 170ml Protects From 100 Illness Causing Germs
# Dettol Handwash Fresh Ph Balanced Liquid Soap Pump 200 ml Protects From 100 Illness Causing Germs
# Akij Daily Hand Wash Ocean Blue (Refill)
# Sepnil Extra Mild Hand Wash Marigold Refill 170.0 ml
# Dettol Handwash Skincare Ph Balanced Liquid Soap Pump 200ml Protects From 100 Illness Causing Germs
# Sepnil Extra Mild Hand Wash Marigold Pump
# Dettol Handwash Re-Energize Ph Balanced Liquid Soap Refill 170ml Protects From 100 Illness Causing Germs
# Sepnil Extra Mild Hand Wash Tea Oil Pump
# Mediker SafeLife Hand Wash Refill with Neem & Olive Oil | Protection from Germs | Fights Bacteria, Virus, Fungi | 170 ml
# YUSERA Hand Wash Strawbery
# Earth Beauty & You Purifying Lime Hand Wash
# Original Source Tropical Coconut & Shea Butter Moisturising Handwash
# Original Source Creamy Vanilla & Raspberry Moisturising Handwash
# Neem Original Nourishing Hand Wash
# Yusera Liquid Hand Wash Mango
# Lifebuoy Handwash Soap Total Refill 170ml (Combo Pack)
# Lifebuoy Handwash (Soap) Total Refill 170ml (Combo Pack)
# Yusera Liquid Hand Wash Orange
# Dettol Handwash Original Pump 200ml Germ Defence Protects From 99.9% Illness Causing Germs
# Dettol Handwash Re-Energize Ph Balanced Liquid Soap 200ml Protects From 100 Illness Causing Germs
# Organikare Lavendar Handwash 250.0 ml
# Mediker SafeLife Hand Wash Pump & Refill Combo Pack with Neem & Olive Oil | Protection from Germs | Fights Bacteria, Virus, Fungi | 370ml
# Dettol Handwash Aloe Vera Pump 200ml Protects From 100 Illness Causing Germs
# Xpel Tea Tree Antibacterial Handwash (Expiry Date - 31/12/2024)
# Raxoll Anti Bacterial Hand Wash Refill
# Earth Beauty & You Purifying Apricot Hand Wash
# Xpel Tea Tree Antibacterial Handwash
# OGX Smoothing Coconut Coffee Scrub and Wash
# Sepnil Fruity Sanitizing Hand Wash Orange ( Refill)
# Sepnil Fruity Sanitizing Hand Wash - Orange
# Raxoll Anti Bacterial Hand Wash Pump
# Dettol Handwash Fresh Ph Balanced Liquid Soap Refill 170 ml Protects From 100 Illness Causing Germs
# Original Source Creamy Vanilla & Raspberry Moisturising Handwash (Expiry Date - 31/12/2024)
# Dettol Handwash Re-Energize Liquid Pump(Play & Win Free Daily Gifts)
# Lemon Antiseptic Handwash Refill Pack
# Dettol Handwash Re-Energize Large Refill pH Balanced Liquid Soap 750ml protects from 100 illness causing germs
# Buy 2 ACI Neem Original Nourishing Hand wash 200ml Get 1 Neem Original Pure Neem Soap 75 gm Free
# Yusera Liquid Hand Wash Lemon
# Dettol Handwash Skincare Ph Balanced Liquid Soap Refill 170ml Protects From 100 Illness Causing Germs
# Lifebuoy Handwash (Soap) Lemon Fresh Refill 170ml
# Lifebuoy Handwash (Soap) Care Refill 170ml
# Godrej Magic Powder-to-Liquid Handwash Refill Pack 9 gm (Makes 200ml Handwash)
# Godrej Magic Handwash Refill Pack  - Lime Aloe Vera (Makes 200ml of Handwash)
# Savlon Handwash Iris 170ml Pouch
# Yusera Liquid Hand Wash Orange Buy One Get One
# Sepnil Fruity Sanitizing Hand Wash - Apple
# Dettol Re-Energize Handwash Pump +Free Sipper (pH-Balanced)
# Himalaya Pure Hands Tulshi & Lemon Hand Wash -
# Nyle Liquid Hand Wash with Aloevera Extracts
# Superdrug Anti-Bacterial Sensitive Hand wash
# Carex Handwash Protect Plus Aloe Vera Antibacterial Hand Wash
# Dove Caring Hand Wash Cucumber & Green Tea Scent
# Simple Kind to Skin Gentle Care Hand wash
# Dettol Aloevera Handwash Pump +Free Sipper 200ml
# Lux Handwash Rose and Almond Oil Refill
# Simple Kind to Skin Moisturising Handwash
# Dettol Handwash (170ml X 2) Re-Energize Ph Balanced Liquid Soap Refill Protects From 100 Illness Causing Germs
# Sepnil Natural Sanitizing Hand Wash Tea Oil ( 10 TAKA OFF )
# Sepnil Natural Sanitizing Hand Wash Marigold ( 10 TAKA OFF )
# Sepnil Fruity Sanitizing Hand Wash Apple ( Refill)
# DABUR SANITIZE Active Care Hand Wash Pump (Buy One Get One) 200ml
# Nyle Liquid Hand Wash Refill Pack with Aloevera Extracts
# DABUR SANITIZE Active Care Hand Wash Pump
# Sepnil Hand wash Refil Meri gold-180ml (Buy-02 Get 01 Free Hand wash Fruity Refil-180ml)
# Lux Handwash Lavender and Lotus Oil Pump
# DABUR SANITIZE Active Care Liquide Hand Wash Refill 170 ml
# Savlon Handwash Antiseptic 170ml Pouch
# Superdrug Antibacterial Original Hand wash
# Superdrug Antibacterial Aloe Vera Handwash -
# Woman's World Hand Wash 400 ml
# Yusera Liquid Hand Wash Strawberry Buy One Get One
# Lifebuoy Handwash Cool Fresh Pump
# Superdrug Antibacterial Nourish Hand wash
# Scraping for keyword: bodywash
# Lux Body Wash Black Orchid Scent & Juniper Oil 245ml
# Lux Body Wash French Rose & Almond
# Lux Body Wash Freesia Scent & Aloe Vera 245ml
# Dettol Body Wash Loofah Free Shower Gel Skincare Rose & Sakura Blossom with 8 Hour Lasting Moisture 250ml
# Irish Spring 5 in 1 Hair Body Wash and Shampoo
# Palmolive Body Wash Absolute Relaxing
# Lux Perfumed Body Wash Magical Orchid
# Lux Perfumed Body Wash Bright Camellia
# St. Ives Refreshing Body Wash Rose Water And Aloe Vera
# Dettol Body Wash Shower Gel Skincare Rose & Sakura Blossom with 8 Hour Lasting Moisture 250ml
# Wow Skin Science Ubtan Body Wash
# St. Ives Soothing Body Wash Oatmeal & Shea Butter
# Lux Delicate Fragrance Body Wash Dewy Sakura
# Play & Win Free Daily Gifts- Dettol Lasting Fresh Bodywash Melon & Cucumber Fragrance
# Le Beau Premium Moisture Body Wash
# Palmolive Body Wash Morning Tonic
# Irish Spring 5 in 1 Body Wash Shampoo
# Dettol Body Wash Refill Skincare Rose & Sakura Blossom with 8 Hours Long Lasting Moisture 170ml Shower Gel
# Aarong Earth Aloe Vera Body Wash
# Dettol Lasting Fresh Body Wash Shower Gel Melon & Cucumber Fragrance with 12 Hour Odour Protection 250ml
# Shower and Refreshment Combo 04 (Ombre  Body Mist - Blue Pearl + Lux Body Wash with Free Loofah)
# OGX Extra Creamy + Coconut Miracle Oil Ultra Moisture Body Wash
# SKINFOOD Lemon Verbena Body Wash
# Lux Perfumed Body Wash Soft Rose
# St. Ives Exfoliating Body Wash Sea Salt And Pacific Kelp
# HAAY Relief Body Wash
# Wow Skin Science Wild Aqua Body Wash
# Dettol Body Wash Shower Gel Original Pine Fragrance with Trusted Protection 250ml
# Dettol Body Wash Refill Lasting Fresh with Refreshing Melon & Cucumber Fragrance, 12 Hours Odour Protection 170ml Shower Gel
# St. Ives Hydrating Body Wash Coconut Water And Orchid
# Lux Body Wash Hydrating Glow Sweet Mixed Berries Fragrance
# Lux Body Wash Healthy Glow Energising Grape Fruit Fragrance
# Mitvana Deep Moisturizing Body Wash With Tulsi & Pomegranate (Expiry Date- 31/8/2024)
# Suave Kids 3 in 1 Shampoo, Conditioner, Body Wash With Shea Butter
# St. Ives Exfoliating Body Wash Pink Lemon & Mandarin Orange
# St. Ives Vanilla & Oat Milk Pampering Body Wash
# The Body Shop Drops Of Light Pure Clarifying Foam Wash (Expiry Date- 31/8/2024)
# Buy 1 Dettol Lasting Fresh Bodywash 250ml with 12 Hour Odour Protection Get Skincare Rose & Sakura Blosom Bodywash 170ml with 8 Hour Lasting Moisture Free
# Buy 1 Dettol Skincare Rose & Sakura Blossom Bodywash 250ml with 8 Hour Lasting Moisture Get Lasting Fresh Melon & Cucumber Bodywash 170ml with 12 Hour Odour Protection Free
# Dettol Lasting Fresh Body Wash (Loofah Free) Shower Gel Melon & Cucumber Fragrance with 12 Hour Odour Protection 250ml
# Irish Spring Deep Action Scrub Exfoliating Face + Body Wash
# Wow Skin Science Strawberry & Peach  Body Wash
# St. Ives Exfoliating Body Wash with Pink Lemon & Mandarin Orange
# St. Ives Energizing Body Wash Cleanser Citrus & Cherry Blossom
# Dettol Original Body Wash (Chorki Subscription Free) Shower Gel Trusted Protection 250ml
# Suave Kids Silly Apple Wonder 3 In 1 Shampoo + Conditioner + Body Wash
# Kodomo Hair & Body Wash
# Cetaphil Restoraderm  Skin Restoring Body Wash
# St. Ives Hydrating Body Wash Coconut Water & Orchid
# Mitvana Deep Moisturizing Body Wash With Tulsi & Pomegranate
# St. Ives Sea Salt & Pacific Kelp Exfoliating Body Wash
# Irish Spring Active Scrub Exfoliating Body Wash
# St. Ives Exfoliating Body Wash Apricot
# Dettol Lasting Fresh Body Wash (Chorki Subscription Free) Shower Gel Melon & Cucumber Fragrance with 12 Hour Odour Protection 250ml
# Aveeno Baby Daily Care Baby Hair & Body Wash
# Irish Spring Deep Action Scrub Exfoliating Body Wash for Men
# Dettol Body Wash Loofah Free Shower Gel Original Pine Fragrance with Trusted Protection 250ml
# St.Ives Exfoliating Fresh Peach & Jasmine Body Wash
# Kodomo Baby Hair & Body Wash Original
# Aveeno Baby Daily Care Hair & Body Wash
# Wow Skin Science Tea Tree and Mint Foaming Body Wash 250ml (Buy 1 Get 1)
# CeraVe Body Wash with Salicylic Acid | Fragrance Free Body Wash to Exfoliate Rough and Bumpy Skin
# Mamaearth Tea Tree Body Wash With Tea Tree and Neem For Skin Purification
# Mamaearth Deeply Nourishing Body Wash For Babies
# Wow Skin Science Rose Otto Foaming Body Wash
# Sebamed Olive Face and Body Wash For Sensitive and Dry Skin pH 5.5
# Shower Essentials Combo (Lux Body Wash French Rose & Almond + Tresemme Colour Revitalise Vibrant Colour Protection Shampoo)
# Dove Body Wash Gentle Exfoliating 200ml
# Dove Go Fresh Energize Body Wash
# Amlaki Brightening Lavender Body Wash
# SKINFOOD Honey Rich Body Wash
# Aveeno Skin Relief Body Wash
# Jigott Edelweiss Perfume Body Wash
# Jigott Hibiscus Perfume Body Wash
# Irish Spring Aloe Vera Body Wash
# Irish Spring Body Wash Moisture Blast
# Mothercare Baby Body Wash
# Aveeno Soothing Body Wash
# It's BOGO Time (Buy DOVE BODY WASH, Get Vaseline Lotion Deep Restore)
# Dettol Moisture Anti-Bacterial Body Wash - Aloe Vera & Avocado
# Aveeno Daily Moisturizing Yogurt Body Wash with Vanilla Scent and Oats
# Palmolive Body Wash Thermal Spa (Massage)
# Buy 1 Get 1 ( Herbal Essences Detox Volume Crimson Orange & Mint Shampoo & Dove Gentle Exfoliating Body Wash )
# St. Ives Soothing Body Wash Oatmeal And Shea Butter
# Dove Go Fresh Fresh Touch Body Wash
# Dove Body Wash Deeply Nourishing 1L
# Dove Go Fresh Revive Body Wash
# Dove Deep Moisture Nourishing Body Wash
# Boroplus Antibacterial + Moisturising Body Wash with Almond Turmeric & Honey
# Mamaearth deeply nourishing body wash for babies
# Irish Spring Body Wash Aloe
# Olay Fresh Outlast Cooling White Strawberry & Mint Body Wash
# Olay Fresh Outlast Body Wash Birch Water & Lavender
# Dove Talco Body Wash
# Aveeno Positively Nourishing Calming Lavender Body Wash
# Dove Gentle Scrub With Exfoliating Minerals Body Wash
# Wow Skin Science Apple Cider Vinegar Body Wash 250ml (Buy 1 Get 1)
# Wow Skin Science Rose Otto Foaming Body Wash 250ml (Buy 1 Get 1)
# Dove Body Wash Fresh Touch 200ml
# Jigott Chrysanthemum Perfume Body Wash
# Jigott Rose Perfume Body Wash
# Cetaphil Ultra Gentle Body Wash Fragrance Free
# Aveeno Daily Moisturizing Body Wash with Soothing Oat
# Irish Spring Charcoal Paraban Free Moisturizing Face and Body Wash
# Wow Skin Science Japanese Cherry Blossom Body Wash
# Wow Skin Science French Lavender & Chamomile Foaming Body Wash
# Wow Skin Science Tea Tree and Mint Foaming Body Wash
# Aveeno Baby Daily Care Baby sensitive skin body wash
# Dettol Antibacterial Body Wash Fresh Citrus & Orange Blossom with 12 Hours Odour Protection Shower Gel (Loofah  Free)
# Cetaphil Ultra Gentle Refreshing Body Wash
# Irish Spring Body Wash Gel Douche Gear Skin Hydration
# Aveeno Daily Moisturising Body Wash
# Aveeno Daily Moisturizing Body Wash
# Dove Body Wash Deeply Nourishing 200ml
# Mothercare All We Know Baby Body Wash
# Aveeno Daily Moisturizing Yogurt Body Wash, with Apricot Scent and Honey
# Aveeno Nourishing Body Wash
# Dove Go Fresh Restore Blue Fig and Orange Blossom Body Wash
# Dove Gentle Exfoliating Nourishing Body Wash
# Dove Nourishing Secrets Restoring Ritual Body Wash
# Dove Purely Pampering Sweet Cream with Peony Body Wash
# Gillette Body Wash Odor Shield
# AVEENO® Stress Relief Body Wash
# DOVE DEEPLY NOURISHING BODY WASH 500ml
# Dove go fresh Body Wash Pear and Aloe Vera
# Lifebuoy Antibacterial Body Wash Total 10
# Lifebuoy Antibacterial Body Wash Nature Pure
# Dettol Skincare Body Wash (Chorki Subscription Free) Shower Gel Rose & Sakura Blossom Fragrance with 8 Hour Long Lasting Moisture 250ml
# Wow Skin Science Apple Cider Vinegar Body Wash
# Wow Skin Science 2 in 1 Oud Body Wash
# Dove Pampering Body Wash Shea Butter with Warm Vanilla
# Johnson's CottonTouch Body Wash
# Aveeno Baby Daily Care Hair And Body Wash For Sensitive Skin
# Mamaearth Vitamin C Body Wash with Vitamin C and Honey for Skin Illumination
# Dove Body Wash Nourishing Secrets 200ml
# Aveeno Skin Relief Moisturising Body Wash
# Dove Silk Glow Body Wash
# Dove deeply Nourishing Body Wash
# Suave Kids Watermelon Wonder 3In1 Shampoo Conditioner & Body Wash
# Irish Spring Sage & Cedar Moisturizing Face And Body Wash
# Wow Skin Science Ubtan Body Wash 250ml (Buy 1 Get 1)
# Wow Skin Science Wild Aqua Body Wash 250ml (Buy 1 Get 1)
# Irish Spring Original Paraban Free Moisturizing Face and Body Wash
# Irish Spring Black MintMoisturizing Face and Body Wash
# Dettol Cool Antibacterial Bodywash Icy Mint & Bergamot
# Dove Nourishing Secrets Glowing Ritual Body Wash
# St. Ives Soothing Oatmeal Shea Butter Body Wash 400ml
# Cussons Baby Hair And Body Wash Mild And Gentle Chamomile Oil
# Cussons Baby Hair And Body Wash Honey And Camomile
# St. Ives Softening Coconut & Orchid Body Wash 400ml
# Dove Go Fresh Cucumber And Green Tea Scent Body Wash
# Dove Body Wash With Pistachio Cream And Magnolia
# Dove Go Gresh Mandarin and Tiare Flower Body Wash
# Victorias Secret Soap & Surf Scrubby Gel Body Wash
# The Body Shop Vitamin C Glow Cleansing Polish
# The Body Shop Tea Tree Skin Clearing Facial Wash
# The Body Shop Aloe Calming Foaming Wash
# Nair Hair Remover Body Wax Strips With Japanese Cherry Blossom & Rice Bran Oil 20Strips
# Scraping for keyword: facewash
# Moisturizing Skin Care Combo (Rajkonna Light Moisturizer + Aarong Earth Honey & Walnut 2-In-1 Face Wash & Scrub)
# Pond's Face Wash Daily 100g
# Ponds Face Wash Bright Beauty
# Himalaya Fresh Start Oil Clear Face Wash Blueberry
# Himalaya Fresh Start Oil Clear Face Wash Peach
# Himalaya Fresh Start Oil Clear Face Wash Lemon
# Himalaya Natural Glow Rose Face Wash
# Himalaya Pollution Detox Charcoal Face Wash
# Skin Cafe Hydrating Hyaluronic Acid Face Wash with Seaweed Extract
# Pond's Face Wash Pure Detox 100g
# Refreshing Beauty COMBO Offer 03 (Rajkonna Glow Booster Facial Wash With Jojoba Beads + Pond's Light Moisturiser Non-Oily Fresh Feel)
# Himalaya Purifying Neem Face Wash
# Lavino Milk Brightening Face Wash
# Aarong Earth Honey & Walnut 2-In-1 Face Wash & Scrub
# Olay Fresh Outlast Cooling White Strawberry & Mint Body Wash
# Pond's Face Wash Oil Control 100g
# Refreshing Beauty COMBO Offer 04 (Rajkonna Acne Fighting Facial Wash With Jojoba Beads + Pond's Light Moisturiser Non-Oily Fresh Feel)
# Himalaya Men Intense Oil Clear Lemon Facewash
# Lavino Neem Purifying Face Wash With 0.5% Salicylic Acid
# Wow Brightening Vitamin C Face Wash
# Nivea Face Wash Milk Delights Caring Rosewater (Sensitive Skin)
# Lilac Advanced Brightening Face Wash Dry And Sensitive Skin
# Skin Care & Cleansing Combo 03 (Rajkonna Sunscreen SPF 40 PA+++ + Skin Cafe Pure & Natural Aloe Vera gel 98% + Ponds Face Wash Daily )
# Aarong Earth Neem Face Wash With Bursting Beads
# Buy Rajkonna Light Moisturizer With Rice Water And Licorice Extract and Get Ponds Face Wash Bright Beauty & Beauty Formulas Activated Charcoal Nose Pore Strips 1 Piece Free
# Soap & Glory Face Soap & Clarity Vitamin C Facial Wash
# B.Tech Expert Neem Oil Control Purifying Face Wash
# Lotus Herbals Teatreewash Tea tree & Cinnamon Anti-acne Oil Control Face wash
# Cetaphil Face Wash Gentle Skin Cleanser For Dry To Normal, Sensitive Skin
# Lily Lemon Facewash Gel
# Studio X Anti Dandruff Shampoo for Men 355ml (50ml Facewash Free)
# Pond's Face Wash Bright Beauty 50g
# Everglow Lemon Face Wash
# Everglow Acne Face Wash Gel
# Buy One Parachute Hair Oil Advansed Aloe Vera Enriched Coconut 250Ml Double Pack Get One Goat Milk Facewash - Glow - 50Gm  Free
# Lotus Herbals Whiteglow Vitamin-C Radiance Face Wash
# Clean & Clear Morning Energy Lemon Fresh Face Wash
# Buy Himalaya Intense Oil Clear Lemon Menz Face Wash 100 ml Get Himalaya Neem Soap 75 gm Free
# Buy One Parachute Hair Oil Advansed Aloe Vera Enriched Coconut 250Ml Double Pack Get One Aloe Vera Facewash - Oil Control - 50Gm Free
# Parachute SkinPure Aloe Vera Brightening Facewash with Green Tea| Oil Control| Bright & Glowing Skin| All Skin Types| No Parabens, Sulphate| Double Pack (100gm x 2)
# Everyuth Naturals Tulsi Turmeric Face Wash
# Black Pearl Charcoal Face Wash
# Buy One Parachute Skinpure Skin Lotion Natural White 300Ml Get One Goat Milk Facewash - Glow - 50Gm Free
# Everyuth Neem Facewash
# Divas Secret Oil Control Face Wash Lemon Extract For Oily Skin
# YC Whitening Face Wash Gold Caviar
# The Man Company Vitamin C Face Wash
# Beardo Combo - Ultra Glow Facewash 100ml & Ultra Glow Face Cream 60g
# Kumarika Oil Control Face Wash
# Buy One Parachute Naturale Shampoo Anti Hair Fall 340Ml Get One Goat Milk Facewash - Glow - 50Gm Free
# Clean & Clear Morning Energy Aqua Splash Face Wash with Cooling Menthol
# Beardo DeTan Coffee Face Wash
# YC Face Wash With Lemon Extract
# Buy One Parachute Naturale Shampoo Nourishing Care 340Ml Get One Orange Facewash - Anti Pimple - 50Gm Free
# Freyias Saffron Daily Face Wash
# Freyias Weekly Peeling Aloe Vera Face Wash 100ml & Divas Secret Intimate Brightening Solution 50 ml Combo
# Buy One Parachute Naturale Shampoo Nourishing Care 340Ml Get One Goat Milk Facewash - Glow - 50Gm Free
# Buy One Livon Hair Serum 100Ml Get One Aloe Vera Facewash - Oil Control - 50Gm  Free
# Neutrogena Oil Free Acne Wash
# Clean & Clear Foaming Facewash for Oily Skin
# Himalaya Oil Clear Lemon Face Wash
# Garnier Bright Complete DUO Action Face Wash 100gm
# Beardo Combo - Activated Charcoal Face Wash 100ml & Beard & Hair Growth Oil 50ml
# Garnier Men Turbo bright Double Action Face Wash
# YC Whitening Face Wash Milk Extract
# YC Oil Control Face Wash For Men
# Studio X Men's Grooming Bundle Pack (Large) - Shampoo 355ml + Facewash 100ml + Soap 125g + Hair Cream 100ml
# Amlaki Sandalwood Glowing Facewash
# Lakme Blush & Glow Strawberry Freshness Gel Face Wash
# Garnier Bright Complete Vitamin C Face Wash 50gm
# Organikare Miracle Face wash
# YC Whitening Face Wash Vitamin C
# Lotus Herbals Teatreewash Tea Tree And Cinnamon Oil Control Face Wash
# Buy One Parachute Naturale Shampoo Anti Hair Fall 340Ml Get One Orange Facewash - Anti Pimple - 50Gm Free
# Studio X Brightening Face wash for Men
# Buy Pond's Face Wash Oil Control 100g and Get Free Cleansing Puff
# YC Whitening Face Wash Neem Extract
# YC Whitening Face Wash Green Tea Extract
# Parachute SkinPure Goat Milk Brightening Facewash| For Bright & Glowing Skin| Prevents Dry & Dull Skin |All Skin Types| No Parabens, Sulphate| 100 gm
# YC Whitening Face Wash Papaya Extract
# Garnier Men Acno Fight Face Wash
# Freyias Weekly Peeling Milk Face Wash
# St. Ives Glowing Apricot Face Wash
# Freyias Weekly Peeling Papaya Facewash
# Aarong Earth Aloe Vera Face Wash
# Freyias Weekly Peeling Aloe Vera Face Wash
# Buy One Livon Hair Serum 100Ml Get One Goat Milk Facewash - Glow - 50Gm  Free
# Keya Seth  Fresh Look Blackberry Face Wash
# Garnier Bright Complete Vitamin C Face Wash 100gm
# Lotus Herbals Neemwash Neem & Clove Purifying Face Wash with active neem slices
# Lily Aloe Facewash Gel
# Keya Seth Fresh Look Neem Face Wash
# Woman’s World Papaya Kojic Face Wash
# NIOR Deep Clean Gel Face Wash Soothing Menthol
# Couple Combo (Face Wash) - Studio X Oil Clear Facewash for Men 100ml & Parachute SkinPure Aloe Vera Brightening Facewash (Oil Control) 100gm
# Buy One Parachute Naturale Shampoo Damage Repair 340Ml Get One Orange Facewash - Anti Pimple - 50Gm  Free
# Everglow Milk Extract Face Wash
# Keya Seth Fresh Look Aloe Vera Face Wash
# Buy One Parachute Skinpure Skin Lotion Natural White 300Ml Get One  Aloe Vera Facewash - Oil Control - 50Gm Free
# Clean & Clear Night Relaxing Deep Cleansing Face Wash
# Pond's Face Wash Daily 50g
# Buy One Parachute Skinpure Aloe Vera Gel 200Ml Get One Orange Facewash - Anti Pimple - 50Gm  Free
# Garnier Pure Active Purifying Face Wash 100g
# Himalaya Men Power Glow Licorice Facewash
# Johnson's Face Care Daily Essentials Refreshing Gel Wash
# Buy 1 Freyias Weekly Peeling Charcoal Facewash 100 ml & Get 1 Facial Razor Free
# Freyias Brightening Oil Control Daily Face Wash
# Keya Seth Fresh Look  Honey Face Wash
# Pond's Face Wash Pure Detox 50g
# Buy 1 Freyias Weekly Peeling Aloe Vera Face Wash 100 ml & Get 1 Facial Razor Free
# Divas Secret Brightening Face Wash Milk & Saffron For Dry Skin
# Pond's Face Wash Oil Control
# St. Ives Blemish Care Tea Tree Face Wash
# Cetaphil Oily Skin Cleanser  (Daily Face Wash For Oily Acne Prone Skin)
# YC Face Wash - Lemon Whitening
# Buy One Parachute Naturale Shampoo Damage Repair 340Ml Get One Goat Milk Facewash - Glow - 50Gm  Free
# Glow & Handsome Facewash Rapid Action Instant Brightness 100g
# SAM BPO+ Cleanser Anti Acne Foaming Face Wash
# Parachute SkinPure Aloe Vera Brightening Facewash with Green Tea| Oil Control| Bright & Glowing Skin| All Skin Types| No Parabens, Sulphate| 50gm (Buy 3 Get 1 Free)
# Beauty and Glow Combo (Lilac 3X Spot Lightener + Ponds Face Wash + Glow & Lovely Face Cream Blemish Balm)
# Parachute SkinPure Orange Brightening Anti Pimple Facewash
# Parachute SkinPure Orange Brightening Facewash (Anti Pimple) 50gm (Buy 3 Get 1 Free)
# Black Pearl Apple Cider Vinegar + Tea Tree Face Wash
# YC Face Wash So White
# YC Facial Fit Expert Acne & Oil Control Face Wash (Blue)
# YC Whitening Face Wash Aloe Vera Extract
# Lotus Herbal Whiteglow Active Skin Whitening + Oil Control Face Wash
# Guerniss Vitamin E Milk Plus Face Wash
# Everglow Cucumber Face Wash
# Clean & Clear Foaming Face Wash
# Beardo Activated Charcoal Face Wash
# Pond's Face Wash Bright Beauty
# Buy One Parachute Hair Oil Advansed Aloe Vera Enriched Coconut 250Ml Double Pack Get One Orange Facewash - Anti Pimple - 50Gm Free
# Buy One Parachute Skinpure Skin Lotion Natural White 300Ml Get One Orange Facewash - Anti Pimple - 50Gm Free
# Parachute SkinPure Goat Milk Brightening Facewash| For Bright & Glowing Skin| Prevents Dry & Dull Skin |All Skin Types| No Parabens, Sulphate| 50gm (Buy 3 Get 1 Free)
# Studio X Oil Clear Face wash for Men
# Amlaki Acne Care Brightening Facewash
# Divas Secret Acne Control Face Wash Neem Extract & Lavender Oil For All Skin Types
# Freyias Weekly Peeling Milk Face Wash 100ml & Divas Secret Intimate Brightening Solution 50 ml Combo
# Glow & Lovely Facewash Instaglow with Multivitamins 100g
# Himalaya Moisturizing Aloe Vera Face Wash
# Parachute SkinPure Vitamin C Brightening Facewash| Anti Spot| Enriched with Orange & Rosehip Seed Oil |For Bright, Spot Free & Glowing Skin| All Skin Types| No Parabens, Sulphate| 50 gm
# Mamaearth Aloe Vera Face Wash
# Neutrogena Clear & Radiant Face Wash with Vitamin C
# YC Whitening Face Wash Cucumber Extract
# Freyias Hydrating Foaming Face Wash
# Pond's Bright Beauty Face Wash
# Earth Beauty & You Kaolin Clay Mineral Face Wash
# Nivea Face Wash Milk Delights Precious Saffron (Normal Skin)
# Himalaya Natural Glow Saffron Face Wash
# Himalaya Men Pimple Clear Neem Facewash
# Parachute SkinPure Goat Milk Brightening Facewash (Glow) 100gm (Get 50gm Facewash FREE)
# Studio X Men's Grooming Bundle Pack (Small) - Shampoo 175ml + Facewash 50ml + Soap 75g + Hair Cream 100ml
# Neutrogena Clear & Defend 2% Salicylic Acid Face Wash
# Freyias Weekly Peeling Charcoal Facewash
# Groome Bird’s Nest Brightening Face Wash
# Dermamate Melasma Solution Face Wash
# NIVEA MEN Dark Spot Reduction Face Wash
# Buy One Parachute Skinpure Aloe Vera Gel 200Ml Get One Aloe Vera Facewash - Oil Control - 50Gm Free
# Wow Skin Science Ubtan Face Wash With Brush
# Clean & Clear Morning Energy Berry Blast Face Wash
# Buy 1 Lily Cucumber Facewash Gel Get 1 Lily Cucumber Facewash Gel Free
# Buy Rajkonna Light Moisturizer With Rice Water And Licorice Extract Get Himalaya Fresh Start Oil Clear Face Wash Peach and Livon Serum Hair Essentials Vitamin E
# Lotus Herbals Whiteglow Advance Pink Glow Face Wash
# Black Pearl Green Tea & Neem Face Wash
# Dr. C. Tuna Calendula Face Wash
# Organikare Aloe Honey Facewash
# Kumano Cosmetics Pharmaact Make Clear Gel Face Wash
# Biluma Advance Skin Brightening Face Wash (Vitamin E)
# Buy 1 Freyia's Sunscreen SPF PA 50 ++ For Oily Skin - 50ml and Get 1 Divas Secret Oil Control Face Wash Lemon Extract For Oily Skin 100ml Free
# Scraping for keyword: lotion
# Parachute SkinPure Skin Lotion Natural Moisture
# Rajkonna Brightening Body Lotion Super Moisture
# Rajkonna Brightening Body Lotion Super Radiant
# Parachute SkinPure Deep Moisture Body Lotion with Shea Butter & Coconut Milk|For Soft, Glowing, Nourished Skin| Repairs Dry Skin| 100% Natural Moisturizers| All Skin Types| 300 ml
# Parachute Skinpure Skin Lotion Natural Moisture 200Ml (Get 100Ml Free)
# Parachute Skinpure Skin Lotion Natural White 200Ml (Get 100Ml Free)
# Lavino Nourishing Lotion+Groome Glow Lip Balm Pretty Pink COMBO offer
# Aveeno Daily Moisturising Body Lotion for Dry Skin
# Nivea Nourishing Cocoa Body Lotion for dry skin
# La Roche-Posay Anthelios Gentle Lotion Kids Sunscreen Spf 50
# Dr. C. Tuna Sun  Face & Body Lotion (Spf 50)
# Aveeno Calm + Restore Soothing Oat Toning Lotion
# Yusera Intense Moisturizing Body Lotion With Extra Virgin Olive Oil
# Cerave AM Facial Moisturizing Lotion with Sunscreen SPF30 Oil-Free
# Pierre Cardin Baby Body Lotion
# YC Baby Lotion
# SKINFOOD Lemon Verbena Body Lotion
# YC Double Milk Moisturizing Lotion
# Parachute SkinPure Skin Lotion Deep Moisture 200ml (50ml Parachute Petroleum Jelly Free)
# Lavino Nourishing Lotion With Shea Butter & Argan Oil
# Revive Moisturizing Lotion
# Refreshing Beauty COMBO Offer 03 (Rajkonna Glow Booster Facial Wash With Jojoba Beads + Pond's Light Moisturiser Non-Oily Fresh Feel)
# Lotus Herbals Teatreewash Tea tree & Cinnamon Anti-acne Oil Control Face wash
# Buy One Parachute Naturale Shampoo Anti Hair Fall 340Ml Get One Goat Milk Facewash - Glow - 50Gm Free
# Freyias Weekly Peeling Aloe Vera Face Wash 100ml & Divas Secret Intimate Brightening Solution 50 ml Combo
# Buy One Livon Hair Serum 100Ml Get One Aloe Vera Facewash - Oil Control - 50Gm  Free
# Lotus Herbals Teatreewash Tea Tree And Cinnamon Oil Control Face Wash
# Buy One Parachute Naturale Shampoo Anti Hair Fall 340Ml Get One Orange Facewash - Anti Pimple - 50Gm Free
# Lotus Herbals Whiteglow 3 in 1 Deep Cleaning Skin Whitening Facial Foam
# Makeup Revolution Skincare Vitamin C Glow Cream Cleanser
# Buy One Parachute Skinpure Skin Lotion Natural White 300Ml Get One  Aloe Vera Facewash - Oil Control - 50Gm Free
# Johnson's Milk and Rice Lotion
# Skinpro Body Lotion
# Johnson's Baby Milk + Rice Lotion  (Malaysia)
# Aveeno Daily Moisturising Body Lotion
# Beauty Formulas Softening Foot Lotion
# Vaseline Intensive Care Advanced Repair Unscented Body Lotion
# St. Ives Renewing Collagen And Elastin Body Lotion
# Parachute SkinPure Natural White Body Lotion with Sandalwood & Coconut Milk|For Bright, Glowing, Nourished Skin| 100% Natural Moisturizers| All Skin Types| 300 ml
# Parachute SkinPure Skin Lotion Natural White 100ml (15ml Petroleum Jelly Free)
# Cerave Daily Moisturising Lotion
# Himalaya Baby Lotion
# Cerave PM Facial Moisturing Lotion Ultra Lightweight
# Dove Body Lotion Nourishing Radiance 250ml
# CeraVe PM Facial Moisturizing Lotion For Normal To Dry Skin
# Aveeno Daily Moisture Lotion
# Buy One Parachute Skinpure Skin Lotion Natural White 300Ml Get One Orange Facewash - Anti Pimple - 50Gm Free
# Parachute SkinPure Natural White Body Lotion with Sandalwood & Coconut Milk|For Bright, Glowing, Nourished Skin| 100% Natural Moisturizers| All Skin Types| 200 ml
# Cerave SA Lotion for Rough & Bumpy Skin
# Kool After Shave Lotion 50.0 ml
# CeraVe Baby Moisturizing Lotion
# Parachute SkinPure Natural Moisture Body Lotion with Olive & Coconut Milk|For Soft, Glowing, Nourished Skin| 100% Natural Moisturizers| All Skin Types| 200 ml
# Parachute SkinPure Natural Moisture Body Lotion with Olive & Coconut Milk|For Soft, Glowing, Nourished Skin| 100% Natural Moisturizers| All Skin Types| 300 ml
# Enchanteur Charming Perfumed Body Lotion
# Vaseline Lotion Mosquito Defense 50ml
# Parachute Just For Baby - Baby lotion
# NIVEA Body Lotion Shea Smooth
# Johnson's Milk+ Rice Lotion
# Aveeno Baby Calming Comfort Bedtime Lotion for Delicate Skin
# Parachute SkinPure Skin Lotion Natural Moisture 200ml (50ml Parachute Petroleum Jelly Free)
# Nivea Rich Nourishing Body Lotion
# La Roche-Posay Anthelios Spf 50 Gentle Lotion Mineral Sunscreen
# Cetaphil Moisturizing Lotion (Normal To Combination, Sensitive Skin)
# Nivea Cocoa Butter Body Lotion Vitamin E Dry Skin
# Enchanteur Elegant Musk Body Lotion
# Guerniss Milk Plus Bright & White Co Enzyme Q10 Body Lotion
# Avene Toning Lotion
# Nivea Shea Smooth Dry Skin Body Lotion With Deep Moisture Serum
# AVEENO BABY DAILY MOISTURE LOTION(227g)
# LA Roche-Posay Anthelios Cooling Water Sunscreen Lotion Spf 60
# CeraVe Moisturising Lotion For Dry To Very Dry Skin
# Johnson & Johnson Baby Lotion
# Garnier Ultimate Blends Mythic Olive Nourishing Body Lotion For Dry Skin
# Biluma Advance Skin Brightening Body Lotion For Even Skin Tone
# Ossum Body Lotion Aloe Vera
# Enchanteur Enticing Satin Smooth Body Lotion
# Boots Cocoa Butter & Vitamin E Body Lotion
# Nivea Intensive Moisture Body Milk Lotion
# Aveeno Skin Relief Moisturising Lotion
# Livon Anti Hairfall Protein Shampoo 300ml (FREE Parachute SkinPure Skin Lotion Natural White 100ml)
# Kodomo Baby Lotion Powder
# Jhonson's Baby Lotion for Baby Soft Skin
# Johnson's Baby Lotion Baby Soft Skin (Malaysia)
# Johnson's Bedtime Baby Lotion 500ml
# Boots cucumber cleansing lotion Sweep the night away 150ml
# Organikare Skin Lotion
# Cerave Ultra-Light Moisturizing Lotion Broad Spectrum Spf 30
# Pond's Body Lotion Moisturising
# Aveeno Skin Relief Moisturising Lotion for Dry Skin
# Vaseline Intensive Care Aloe Soothe Body Lotion
# Nivea Men After Shave Lotion Sensitive
# Parachute SkinPure Skin Lotion Natural White  (100ml Natural Moisture Lotion Free)
# Revive Perfect Skin Moisturizing Lotion
# Enchanteur Alluring Perfumed Body Lotion
# Parachute Just For Baby - Milky Glow Lotion
# Johnson's Baby Lotion Soap
# Dove Baby Lotion Sensitive Moisture
# Parachute Just for Baby - Baby Lotion 200ml (Baby Face Cream 50g FREE)
# Nivea Body Lotion Irresistibly Smooth
# Parachute Just for Baby - Baby Lotion 200ml (Baby Wash 100ml FREE)
# Wow Skin Science Anti Pollution Sunscreen Spf 40 Lotion
# Aveeno Baby Daily Care Baby Moisturising Lotion
# NIVEA Body Lotion Express Hydration
# Guerniss Green Tea Moisturizing Body Lotion ( Expire Date:Nov-2024)
# Kodomo Baby Lotion Powder Extra Mild For 0+ Age
# Vaseline Lotion Mosquito Defense
# Cetaphil Dam Daily Advance Ultra Hydrating Lotion
# Ossum Body Lotion Rose
# Ossum Body Lotion Olive
# Baby Soft Baby Lotion 100 ml
# Cerave AM Facial Moisturing Lotion with Sunscreen - Broad Spectrum SPF 30
# ASDA Little Angels Baby Lotion
# Cerave Hydrating Mineral Sunscreen SPF 30 Body Lotion
# Dove Baby Rich Moisture Nourishing Baby Lotion
# Parachute SkinPure Skin Lotion Deep Moisture 200ml (100ml Petroleum Jelly Free)
# Parachute SkinPure Skin Lotion Natural Moisture 100ml (15ml Petroleum Jelly Free)
# Vaseline Lotion Healthy Bright
# Parachute SkinPure Skin Lotion Natural Moisture 300ml (100ml Body Lotion Free)
# Lakmé Sun Expert SPF 50 PA+++ Ultra Matte Lotion
# Buy Rajkonna Brightening Lotion Get Vasline Rosy Lips FREE
# Parachute SkinPure Deep Moisture Body Lotion with Shea Butter & Coconut Milk|For Soft, Glowing, Nourished Skin| Repairs Dry Skin| 100% Natural Moisturizers| All Skin Types| 200 ml
# Vaseline Intensive Care Dry Skin Repair Moisturising Body Lotion
# Johnson's Baby Milk+Rice Lotion
# Cerave Itch Relief Moisturizing Lotion
# Ossum Body Lotion Cocoa Butter
# Cetaphil Baby Daily Lotion with Organic Calendula
# Vaseline Nourishing Argan Oil Body Lotion
# Johnson's Baby Milk + Rice Lotion(Malaysia)
# Guerniss Shea Butter Body Lotion ( Expire Date:Nov-2024)
# Pierre Cardin Secret Paradise Body Lotion With Babobab Oil
# Meril Baby Lotion
# Parachute SkinPure Skin Lotion Deep Moisture 300ml (100ml Lotion Free)
# Nivea Body Lotion Sensual Musk
# Parachute SkinPure Natural White Body Lotion with Sandalwood & Coconut Milk|For Bright, Glowing, Nourished Skin| 100% Natural Moisturizers| All Skin Types| 100 ml
# LA Roche-Posay Anthelios Gentle Mineral Sunscreen Lotion SPF 50
# Blaze O Skin Body Lotion Moonlight Aurora
# La Roche Posay Anthelios Cooling Water Lotion Face And Body Sunscreen Spf 30
# Embla Daily Moisture Baby Lotion
# Guerniss Shea Butter Body Lotion
# Garnier Ultimate Blends Soothing & Hydrating Delicate Oat Body Lotion For Dry & Sensitive Skin
# Lakme Sun Expert SPF 24 Ultra Matte Lotion
# Palmer's Skin Success Fade Milk Tone Correcting Body Lotion
# Aveeno daily moisturizing lotion hydratante quotidienne
# Elizabeth Arden Green Tea Lotion
# Chanel Coco Noir Hydrationg Body Lotion
# Blaze O Skin Body Lotion Amber Sunshine
# Dr. C. Tuna Calendula Oil Body Lotion
# Dior Fahrenheit After Shave Lotion
# Shoi Double Layered Comfortable Chikan Cotton Bra Black
# Glow & Handsome Facewash Rapid Action Instant Brightness 50g
# Garnier Bright Complete DUO Action Face Wash 100gm
# Darlie Double Action Toothpaste
# Shoi Double Layered Comfortable Chikan Cotton Bra Pink
# Colormax Diva Glamour Matte Lipcolour - London
# Ligion Stylish Hair Gel Ocean
# Glow & Handsome Facewash Rapid Action Instant Brightness 100g
# Scraping for keyword: cream
# 3W Clinic Intensive UV Sunblock Cream SPF 50+PA+++
# Moisturizing Skin Care Combo (Rajkonna Light Moisturizer + Aarong Earth Honey & Walnut 2-In-1 Face Wash & Scrub)
# Glow & Lovely Face Cream (BB) Blemish Balm 40g
# Nivea Soft Jar Moisturising Cream
# Ponds BB+ Cream Instant Spot Coverage + Light Make-up Glow Ivory
# Himalaya Natural Glow Saffron Face Cream
# Glow & Lovely Face Cream (BB) Blemish Balm 18g
# Parachute SkinPure Skin Lotion Natural Moisture
# Parachute SkinPure Skin Lotion Natural White 100ml (15ml Petroleum Jelly Free)
# Parachute SkinPure Natural White Body Lotion with Sandalwood & Coconut Milk|For Bright, Glowing, Nourished Skin| 100% Natural Moisturizers| All Skin Types| 200 ml
# Cerave SA Lotion for Rough & Bumpy Skin
# Enchanteur Elegant Musk Body Lotion
# Buy One Parachute Skinpure Skin Lotion Natural White 300Ml Get One  Aloe Vera Facewash - Oil Control - 50Gm Free
# Ligion Nail Color Cream
# Armela Kitty Teenage Cotton Panty - Butter Cream
# Koelcia AC Care Foam Cleanser
# Himalaya Nourshing Skin Cream
# Nirvana Color Smart Coverage Bb Cream With Spf 15 - Light
# Makeup & Cleansing Combo 2 ( Nirvana Color Lipstick - Infatuated, Skin Cafe Micellar Water, Ponds BB+ Cream - Ivory)
# Skin Care & Cleansing Combo 03 (Rajkonna Sunscreen SPF 40 PA+++ + Skin Cafe Pure & Natural Aloe Vera gel 98% + Ponds Face Wash Daily )
# Parachute SkinPure Aloe Vera Gel | 99% Pure Aloe| For Soft, Moisturized & Hydrated Skin| Heals, Repairs, Protects Skin| 8h moisturization| Soothes Sunburn| All Skin Types | 100 ml
# Care:Nel Anti-Melasma Cica Cream
# Parachute SkinPure Deep Moisture Body Lotion with Shea Butter & Coconut Milk|For Soft, Glowing, Nourished Skin| Repairs Dry Skin| 100% Natural Moisturizers| All Skin Types| 300 ml
# Glo On Pink Glow Cream with American Skin Technology | Enriched with Vitamin C,E, B3 & Glow Boosters| For Bright, Glowing, Spot Less Skin| Sun Protection| All Skin Types| 25 gm
# Cosrx Advanced Snail 96 Mucin Power Essence
# Buy Rajkonna Light Moisturizer With Rice Water And Licorice Extract and Get Ponds Face Wash Bright Beauty & Beauty Formulas Activated Charcoal Nose Pore Strips 1 Piece Free
# Parachute Skinpure Skin Lotion Natural Moisture 200Ml (Get 100Ml Free)
# Parachute SkinPure Aloe Vera Gel | 99% Pure Aloe| For Soft, Moisturized & Hydrated Skin| Heals, Repairs, Protects Skin| 8h moisturization| Soothes Sunburn| All Skin Types | 50 ml
# Pond’s Serum Cream Bright Beauty 35g
# Veet Pure™ Hair Removal Cream 25g Normal Skin for Body & Legs, Freshest Smell with Cucumber Extract Leaves Skin Feeling Smooth, Moisturized & Visibly Glowing, Dermatologically Tested
# Parachute Just For Baby - Milky Glow Face Cream
# Pantene Pro-V Hair Oil Replacement Leave On Cream Super Food
# Medi-Peel Melanon X Cream
# LBT Low Rise Stylish Lace Panty - Vanilla Cream
# SAM SPF 50+ Cream Board Spectrum Sunscreen
# SAM Moist Cream
# Glow & Lovely Cream Winter  (Aloe Fresh Petroleum Jelly 9ml Free)
# Buy 1 Nivea Express Hydration 380 ml Get (Nivea Essential Lip Balm And Nivea Soft Jar Moisturizing Cream 50 ml Free)
# Biluma Advance Skin Brightening Day Cream For Even Skin Tone, Blended With Vitamin E & Natural Ingredients For Dark Spots
# Cetaphil Bright Healthy Radiance (BHR) Brightening Night Comfort Cream
# Cetaphil Bright Healthy Radiance Brightness Reveal Creamy Cleanser
# Cetaphil Pro Dryness Control Day Protect Hand Cream
# Thank You Farmer Be Beautiful Natural BB Cream SPF30 PA++
# Streax Professional Argan Secrets Hair Colourant Cream - Natural Black 1
# Sinoz Acne Free Cream
# Original Source Creamy Vanilla & Raspberry Moisturising Handwash
# Palmer's Cocoa Butter Formula Foot Magic Cream
# CeraVe Acne Foaming Cream Cleanser
# Maybelline New York Dream Brightening Creamy Concealer Light 20
# Glow & Lovely Cream Winter 25g
# No7 Hydra Luminous Water Surge Gel Cream
# Farmasi BB Cream Light To Medium 02
# Keya Seth Skin Defence Cream Orange
# Pierre Cardin Sun Cream 30 Spf High Protection
# Pierre Cardin Protective Sun Cream 50+ Spf Very High Protection
# Shoi Double Layered Regular Use Cotton Bra Cream
# Palmer's Coconut Oil Formula Coconut Oil Hand Cream
# Nagano Creamy Eye Treatment with Vitamin E
# Flormar Compact Powder - 091 Medium Cream Rose
# Palmer’s Skin Success Anti-Dark Spot Fade Cream
# Superdrug Naturally Radiant Renewing Night Cream
# Note BB Cream 02
# Parachute Hair Oil Anti Hairfall Oil Extra Care 300ml (Root Applier) & Glo-On Pink Glow Cream 50gm Combo
# Parachute SkinPure Aloe Vera Brightening Facewash (Oil Control) 100gm & GLO-ON Pink Glow Cream 50gm Combo
# Creme 21 All Day Cream With Vitamin E
# OLIVE Papaya Day Cream
# Beardo Combo - Ultra Glow Face Cream 60g & Activated Charcoal Face Wash 100ml
# YC Anti Bacteria Shower Cream Green Tea
# CeraVe Skin Renewing Peptide Eye Cream
# Diva's Secret Oil Balancing Serum Cream 60gm
# Neutrogena Hydro Boost Hand Gel Cream
# Glow & Lovely Face Cream Ayurvedic Care 25g
# CeraVe Baby Moisturizing Cream
# Sinoz Anti-Dark Spot Sunscreen Cream SPF 50+
# Shoi Front Cross Strap Double Layered Cotton Bra Cream
# Olay Total Effect 7 in 1 day Cream SPF 15 Gentle 50 gm
# Fruit of The Earth Vitamin E Skin Care Cream
# LABONNO Strawberry Buttery Massage Cream
# Olay Natural Aura Glowing Radiance Cream SPF15 with Mulberry Extract
# Olay Vitamin C + Aha24 Day Gel Face Cream
# Glow & Lovely Face Cream Advanced Multivitamin 23g
# YC Milky Shower Cream With Sponge
# Lotus Herbal Whiteglow Skin Whitening & Brigntening Gel Crème spf-25 PA+++ 35gms
# Glo On Pink Glow Cream with American Skin Technology | Enriched with Vitamin C,E, B3 & Glow Boosters| For Bright, Glowing, Spot Less Skin| Sun Protection| All Skin Types| Pack of 2 (50gm X 2)
# Aveeno Baby Soothing Relief Emollient Cream
# TIA'M My Signature Panthenol Moist Cream
# Innisfree jeju Cherry Blossom Glow Tone-up Cream
# TIA'M AC Fighting Spot RX Cream
# Porcelana Night time Hydration Cream
# Aveeno Daily Moisturising Hand Cream
# Parachute Hair Oil Advansed Aloe Vera Enriched Coconut 150ml & GLO-ON Pink Glow Cream 50gm Combo
# Makeup Revolution Skincare Brightening Boost Cream Ginseng Eye Cream
# Fadeout Anti-Wrinkle Whitening Night Cream
# Lotus Herbals Whiteglow Vitamin-C Radiance Cream Spf 20
# ...
# Buy Rajkonna Light Moisturizer With Rice Water And Licorice Extract and Get Ponds Face Wash Bright Beauty & Beauty Formulas Activated Charcoal Nose Pore Strips 1 Piece Free
# Cetaphil Restoderm Skin Restoring Body Moisturizer
# Yusera Brightening Moisturizer With Extra Virjin Olive Oil
# CeraVe Moisturizing Cream For Dry to Very Dry Skin
# Dettol Soap Skincare 100gm Bathing Bar, Soap with 2X Moisturizers & Argan Oil
# Freyias Oil Control Glow Boost Moisturizer 50ml And Freyias Strawberry LipGlam 4ml Combo
# Parachute SkinPure Deep Moisture Body Lotion with Shea Butter & Coconut Milk|For Soft, Glowing, Nourished Skin| Repairs Dry Skin| 100% Natural Moisturizers| All Skin Types| 200 ml
# Buy 1 Freyias Vitamin E Glow Boost Moisturizer 50 ml & Get 1 Freyias Hydrating Toner For Dry Skin 20 ml Free
# Cerave Moisturizing Cream For Normal To Dry Skin
# Scraping for keyword: soap
# Refreshing Beauty COMBO Offer 03 (Rajkonna Glow Booster Facial Wash With Jojoba Beads + Pond's Light Moisturiser Non-Oily Fresh Feel)
# Livon Hair Serum with Argan Oil & Vitamin E for Women & Men| For Frizz Free, Smooth & Glossy Hair| Moisturizes & Detangles Hair| All Hair Types| 50 ml
# Organikaon Bright Skin Combo (Organikaon Saffron Goat Milk Soap 100.0 gm + Organikaon Kumkumadi Oil 30.0 ml )
# Organikaon Saffron Goat Milk Soap
# Actisef Original Soap 75g (Buy 3 Get 1)
# Actisef Nourish Soap 75g (Buy 3 Get 1)
# Refreshing Beauty COMBO Offer 04 (Rajkonna Acne Fighting Facial Wash With Jojoba Beads + Pond's Light Moisturiser Non-Oily Fresh Feel)
# Dove Beauty Bar Soap White 135g (Bundle of 2)
# Godrej No.1 Rose Soap 75 gm (Pack Of 4)
# Raxoll  Germ Shield Plus Care Soap
# Yardley London English Rose Soap
# Dettol Soap Original 75g Germ Defence – Protects From 99.99% Germs
# Lifebuoy Skin Cleansing Soap Bar Total 150g (Bundle of 3)
# Dove Beauty Bar Soap Pink 135g (Bundle of 2)
# Lux Soap Bar Soft Glow 100g (Bundle of 3)
# Godrej Cinthol Soap Lime
# Johnson's Baby Soap
# Lifebuoy Handwash (Soap) Total Refill 170ml (Combo Pack)
# Lifebuoy Handwash Soap Total Refill 170ml (Combo Pack)
# Lifebuoy Skin Cleansing Soap Bar Care 100g
# Lux Soap Bar Velvet Glow  (Combo Pack)
# Parachute Just for Baby - Baby Wash (Baby Soap 75g Free)
# Dettol Original Bathing Soap Bar  Germ Defence(Play & Win Free Daily Gifts)
# RIBANA Make-up Remover Soap
# Lux Soap Bar Soft Glow 150g
# Himalaya Neem & Turmeric Soap
# Focallure Brow Styling Soap With Knife (Fa182)
# RIBANA Goats Milk Soap
# Baby Soap - Parachute Just for Baby
# Studio X Anti Dandruff Shampoo for Men 175ml (75gm Soap Free)
# Studio X Men's Grooming Bundle Pack (Large) - Shampoo 355ml + Facewash 100ml + Soap 125g + Hair Cream 100ml
# Godrej No 1 Rose Soap 100 gm (Buy 3 Get 1 Free)
# Kumarika Herbal Beauty Soap 100g  (Buy 3 Get 1)
# Godrej No.1 Sandal Soap 75 gm (Pack Of 4)
# Buy 2 Himalaya Gentle Baby Soap 75 gm Get 1 Himalaya Gentle Baby Soap 75 gm Free
# Studio X Clean & Fresh Soap For Men Combo Pack (125gm x 3)
# Johnson's Baby Lotion Soap
# Buy 1 Studio X Clean & Strong Shampoo for Men 355ml Get 2 Studio X Soap 75gm Free
# Dettol Mini Soap Skincare 30g With Moisturizers
# Meril Milk & Rose Soap Bar
# Dettol Soap Original 100gm Germ Defence Bathing Bar, Soap with protection from 99.99% illness-causing germs
# Dettol Soap Cool 75g Upto 5°C Cooler Sensation & Odour Protection
# Lifebuoy Skin Cleansing Soap Bar Care (Combo Pack)
# YC Herbal Extracts Acne Facial Soap
# Dettol Soap Pack of 4 Variants (75gm x 4)- Original, Skincare, Cool & Citrus Fresh Soaps
# Free 25g Extra with Dettol Soap Cool Odour Protection 125g upto 5°C Cooler Sensation & Odour Protection
# Enchanteur Perfumed Soap Charming
# Godrej No 1 Jasmine Soap 75 gm
# Dr. C. Tuna Calendula Soap
# Dr. C. Tuna White + Correct Brightening Soap
# Lux Soap Bar Soft Glow 150g (Bundle of 3)
# Yardley Imperial Jasmine Soap
# Godrej No 1 Lime Soap 75 gm
# GODREJ CINTHOL SOAP  HEALTH+
# Godrej No 1 Lime Soap
# Dettol Handwash Fresh Ph Balanced Liquid Soap Pump 200 ml Protects From 100 Illness Causing Germs
# Lifebuoy Handwash (Soap) Lemon Fresh Pump
# Ireneda Brows Up Clear Eyebrow Styling Soap - 8g (IR-E06)
# Comely Handmade Soap (Pink Lily)
# Dettol Soap Skincare 125gm Bathing Bar, Soap with Moisturizers
# Dettol Mini Soap Fresh Citrus 30g with Odour Protection
# Soap & Glory’s The Rushower Dry Shampoo
# Studio X Clean & Fresh Soap For Men Combo Pack (75gm x 4)
# Studio X Clean & Fresh Soap for Men
# Kodomo Baby Soap - Sensitive
# Parachute Just for Baby - Baby Powder (Baby Soap 75g Free)
# Baby Soft Baby Soap 75 gm
# Dettol Handwash Skincare Ph Balanced Liquid Soap Pump 200ml Protects From 100 Illness Causing Germs
# Meril Milk & Rose Soap Bar ( 5 TAKA OFF )
# Dettol Handwash Re-Energize Ph Balanced Liquid Soap Refill 170ml Protects From 100 Illness Causing Germs
# RIBANA Saffron Goats Milk Soap
# Godrej No 1 Jasmine Soap 100 gm (Buy 2 Get 15tk Off)
# Lifebuoy Skin Cleansing Soap Bar Total 100g (Combo Pack)
# Lifebuoy Skin Cleansing Soap Bar Lemon Fresh 100g (Bundle of 4)
# Comely Handmade Soap (Sunshine Garden)
# Soap & Glory Face Soap & Clarity Vitamin C Facial Wash
# Yardley London Antibacterial Soap Morning Fresh for Women
# Amlaki Hand Made Herbal Soap
# Buy 1 Studio X Anti Dandruff Shampoo for Men 355ml Get 2 Studio X Soap 75gm Free
# Soap & Glory Clean On Me Creamy Shower Gel
# Lifebuoy Skin Cleansing Soap Bar Total 150g
# Lifebuoy Handwash (Soap) Care Pump 200ml
# Yardley London English Lavender Soap
# Buy Himalaya Intense Oil Clear Lemon Menz Face Wash 100 ml Get Himalaya Neem Soap 75 gm Free
# Amlaki Goat Milk Brightening Soap
# Fa Inspiring Passion Fruit Soap
# Dettol Soap Cool 125g Upto 5°C Cooler Sensation & Odour Protection
# Meril Milk & Beli Soap Bar
# Yardley London Antibacterial Soap Lavender for Women
# Godrej No 1 Rose Soap 75 gm
# RIBANA Activated Carbon Soap
# GODREJ NO 1 ROSE SOAP
# Lux Soap Bar Velvet Glow 150g (Bundle of 3)
# Lifebuoy Handwash (Soap) Care Refill 170ml (Combo Pack)
# Dettol Handwash Cool Ph Balanced Liquid Soap Refill 170ml Protects From 100 Illness Causing Germs
# Parachute Just for Baby - Baby Shampoo (Baby Soap 75g Free)
# Himalaya Neem & Turmeric Soap (Buy 3 Get 1 Free)
# Shower Essentials Combo 01 (Rajkonna White Glow Shower Gel + Skinlogic Body Gloves 1 Pair Pink)
# Shower and Refreshment Combo 04 (Ombre  Body Mist - Blue Pearl + Lux Body Wash with Free Loofah)
# Enchanteur Perfumed Soap Magic
# Lux Soap Bar Soft Glow 100g (25g Extra)
# Dr. C. Tuna Baby Soap
# Yardley London Luxury Soap Buy 2 Get 1 Free
# Parachute Just For Baby - Milky Glow Saffron & Milk Soap Pack of 2 Combo (75g x 2)
# Skincare Combo 01 (Rajkonna Facial Wash + Parachute Aloe Vera gel)
# Lux Soap Bar Bright Glow 100g
# Lifebuoy Soap Bar Care 150gX3 Multipack
# Lux Soap Bar Flawless Glow 100g
# Lux Soap Bar Bright Glow 75g
# Lux Soap Bar Flawless Glow 75g
# Parachute Naturale Nourishing Care Shampoo with Aloe Vera & Coconut Milk| For Strong & Silky Hair| Smoothens Hair| Paraben Free, 100% Vegan| All Hair Types| 170 ml
# Livon Hair Serum with Argan Oil & Vitamin E for Women & Men| For Frizz Free, Smooth & Glossy Hair| Moisturizes & Detangles Hair| All Hair Types| 18 ml
# Parachute Naturale Damage Repair Shampoo with Red Hibiscus & Coconut Milk| For Strong & Soft Hair| Smoothens Rough Hair| Paraben Free, 100% Vegan| All Hair Types| 170 ml
# Buy Rajkonna All Purpose Toner and Get Pond's Light Moisturiser Non-Oily Fresh Feel Free
# Parachute Advansed Onion Hair Growth Oil 200ml & Parachute Naturale Shampoo Onion Hair Fall Control 345ml Combo
# Parachute SkinPure Aloe Vera Gel | 99% Pure Aloe| For Soft, Moisturized & Hydrated Skin| Heals, Repairs, Protects Skin| 8h moisturization| Soothes Sunburn| All Skin Types | 100 ml
# Parachute SkinPure Deep Moisture Body Lotion with Shea Butter & Coconut Milk|For Soft, Glowing, Nourished Skin| Repairs Dry Skin| 100% Natural Moisturizers| All Skin Types| 300 ml
# Glo On Pink Glow Cream with American Skin Technology | Enriched with Vitamin C,E, B3 & Glow Boosters| For Bright, Glowing, Spot Less Skin| Sun Protection| All Skin Types| 25 gm
# Mediker SafeLife Hand Wash Refill Combo Pack with Neem & Olive Oil | Protection from Germs | Fights Bacteria, Virus, Fungi | (170ml X 2pcs)
# Parachute SkinPure Aloe Vera Gel | 99% Pure Aloe| For Soft, Moisturized & Hydrated Skin| Heals, Repairs, Protects Skin| 8h moisturization| Soothes Sunburn| All Skin Types | 50 ml
# Rongdhonu Senna Leaf -Sonapata Powder
# Shoi Front Cross Strap Double Layered Cotton Bra Pink
# Studio X Anti Dandruff Shampoo for Men 355ml (50ml Facewash Free)
# The Body Shop Roots of Strength™ Firming Shaping Serum
# Shoi Double Layered Comfortable Chikan Cotton Bra Pink
# Valene Sweet Mom Maternity Nursing Bra-Pale Brown
# Armela Princess of Sixteen Teenage Bra-Powder Blue
# Parachute SkinPure Skin Lotion Deep Moisture 200ml (50ml Parachute Petroleum Jelly Free)
# Parachute SkinPure Skin Lotion Natural Moisture 200ml (Free SkinPure Aloe Vera Gel 50g)
# Parachute SkinPure Skin Lotion Natural White 200ml (50ml Parachute Petroleum Jelly Free)
# Glow & Handsome Facewash Rapid Action Instant Brightness 100g
# Couple Combo (Shampoo) - Studio X Clean & Strong Shampoo for Men 355ml & Parachute Naturale Shampoo Anti Hair Fall 340ml
# Couple Combo (Shampoo) - Studio X Anti Dandruff Shampoo for Men 355ml & Parachute Naturale Shampoo Nourishing Care 340ml
# Studio X Anti Dandruff Shampoo for Men
# Buy One Livon Hair Serum 100Ml Get One Orange Facewash - Anti Pimple - 50Gm  Free
# Couple Combo (Face Wash) - Studio X Brightening Facewash for Men 100ml & Parachute SkinPure Goat Milk Brightening Facewash (Glow) 100gm
# Parachute SkinPure Aloe Vera Brightening Facewash with Green Tea| Oil Control| Bright & Glowing Skin| All Skin Types| No Parabens, Sulphate| 100 gm
# Buy One Parachute Naturale Shampoo Damage Repair 340Ml Get One Aloe Vera Facewash - Oil Control - 50Gm Free
# Glo On Pink Glow Cream with American Skin Technology | Enriched with Vitamin C,E, B3 & Glow Boosters| For Bright, Glowing, Spot Less Skin| Sun Protection| All Skin Types| Pack of 2 (50gm X 2)
# Parlour Massage Comb-Round Shape
# Buy 1 Red King Men'S Cooling Oil 100Ml Get 12 Pcs Damage Repair Shampoo Free
# Parachute Hair Oil Advansed Aloe Vera Enriched Coconut 150ml & GLO-ON Pink Glow Cream 50gm Combo
# Himalaya Herbals Complete Care Toothpaste
# Buy 1 Red King Men'S Cooling Oil 100Ml Get 12 Pcs Nourishing Care Shampoo Free
# Parachute Skinpure Orange Brightening Facewash (Anti Pimple) Double Pack (100Gm X 2)
# Mediker SafeLife Hand Wash Pump & Refill Combo Pack with Neem & Olive Oil | Protection from Germs | Fights Bacteria, Virus, Fungi | 370ml
# Buy Parachute Naturale Shampoo Nourishing Care 340ml Get GLO-ON Pink Glow Cream 50gm Free
# Parlour Massage comb-Rectangular Shape
# Freesia Comfy Wireless T-Shirt Bra - Pink
# Parachute Advansed Aloe Vera Enriched Coconut Hair Oil | For Strong, Soft & Silky Hair|Deep Nourishment & Conditioning| All hair Types| 5.1 Fl.oz. (150ml)
# Parachute Advansed Aloe Vera Enriched Coconut Hair Oil | For Strong, Soft & Silky Hair|Deep Nourishment & Conditioning| All hair Types| 5.1 Fl.oz. (250ml)
# Studio X Anti Dandruff Shampoo for Men (5ml X 12 pcs)
# Livon Hair Serum with Argan Oil & Vitamin E for Women & Men| For Frizz Free, Smooth & Glossy Hair| Moisturizes & Detangles Hair| All Hair Types| 100 ml
# Studio X Clean & Strong Shampoo for Men
# Mediker SafeLife Hand Wash Pump Combo Pack with Neem & Olive Oil | Protection from Germs | Fights Bacteria, Virus, Fungi | (200ml X 2pcs)
# Argeville USA Beauty Care Face Out-For Black Spot Mask on Face
# Parachute SkinPure Skin Lotion Natural Moisture 200ml (50ml Parachute Petroleum Jelly Free)
# Buy One Parachute Naturale Shampoo Anti Hair Fall 340Ml Get One Orange Facewash - Anti Pimple - 50Gm Free
# Pepsodent Toothpaste Sensitive Expert Professional 140g
# Glo On Pink Glow Cream with American Skin Technology | Enriched with Vitamin C,E, B3 & Glow Boosters| For Bright, Glowing, Spot Less Skin| Sun Protection| All Skin Types| 50 gm
# Parachute Naturale Shampoo Anti Hair Fall 340ml & Parachute Advansed Onion Enriched Coconut Hair Growth Oil 200ml Combo
# Red King Men’s Cooling Oil with 18 Natural Ingredients, Amla & Menthol Crystals| Gives Calm, Cooling Effect| Relieves Headache, Stress, Fatigue| Helps Relax, Recharge & Sleep| 100 ml
# Parachute SkinPure Natural White Body Lotion with Sandalwood & Coconut Milk|For Bright, Glowing, Nourished Skin| 100% Natural Moisturizers| All Skin Types| 100 ml
# Scraping for keyword: petroleumjelly
# Parachute SkinPure Petroleum Jelly 15ml
# Parachute SkinPure Skin Lotion Deep Moisture 200ml (100ml Petroleum Jelly Free)
# Parachute SkinPure Skin Lotion Natural White 100ml (15ml Petroleum Jelly Free)
# Organikare Petroleum Jelly
# Dabur Herbolene Aloe Petroleum Jelly 2 In 1 With Aloe Vera And Vitamin E
# Parachute SkinPure Skin Lotion Natural Moisture 200ml (50ml Parachute Petroleum Jelly Free)
# Vaseline Petroleum Jelly Original
# Glow & Lovely Cream Winter  (Aloe Fresh Petroleum Jelly 9ml Free)
# Parachute SkinPure Skin Lotion Deep Moisture 200ml (50ml Parachute Petroleum Jelly Free)
# Parachute SkinPure Skin Lotion Natural White 200ml (50ml Parachute Petroleum Jelly Free)
# Saffola Honey 250gm (50ml Petroleum Jelly Free)
# Parachute SkinPure Skin Lotion Natural Moisture 100ml (15ml Petroleum Jelly Free)
# Saffola Honey 100gm (15ml Petroleum Jelly Free)
# Meril Petroleum Jelly With Pure Aloe Vera Extract
# Parachute SkinPure Petroleum Jelly Enriched with Aloe Vera & Cocolipid| For Soft, Glowing Skin| Dry Skin & Lip Repair| Paraben, Sulphate Free| 100 ml
# Parachute SkinPure Petroleum Jelly Enriched with Aloe Vera & Cocolipid| For Soft, Glowing Skin| Dry Skin & Lip Repair| Paraben, Sulphate Free| 50 ml
# Meril Petroleum Jelly
# Vaseline Petroleum Jelly 9ml
# Vaseline Blue Seal  Petroleum Jelly Original
# Vaseline Blue Seal  Petroleum Jelly Vitamin E
# Vaseline Petroleum Jelly 50ml
# Vaseline Blue Seal Aloe Fresh Petroleum Jelly
# Vaseline Petroleum Jelly Cocoa Butter
# Vaseline Blue Seal Vitamin E Petroleum Jelly
# Vaseline Petroleum Jelly Aloe Fresh
# SMC Petroleum Jelly 15 ml Round
# Vaseline Blue Seal  Petroleum Jelly Cocoa Butter
# Dabur Vatika Petroleum Jelly With Vitamin E 9 ml (Pack of 4)
# Meril Petroleum Jelly With Aloe Vera Extract
# Dabur Herbolene Aloe Petroleum Jelly with Aloe Vera & Vitamin E
# Dabur Vatika Petroleum Jelly with Vitamin-E
# Parachute SkinPure Beauty Olive Oil 200ml (50ml Petroleum Jelly Free)
# Vaseline Blueseal Original Pure Petroleum Jelly (Expiry Date - 30/04/2024)
# SMC Petroleum Jelly 50 ml square
# Joya Sanitary Napkin - Wings Regular 8 Pads Pack 80-90g (Buy One Get 15ml SMC Petroleum Jelly  free)
# Dabur Honey: 100% Pure Honey with No Sugar Adulteration (Free 2 Pcs Vatika Petroleum Jelly 9 ml) 250 gm
# Vaseline Lotion Deep Restore 300 ml With Vaseline Petroleum Jelly Free 50 ml
# Buy Vaseline Lotion Healthy Bright 300ml Get Vaseline Petroleum Jelly 50 ml Free
# Dabur Honey: 100% Pure Honey with No Sugar Adulteration (Free Vatika Petroleum Jelly 9 ml) 100 gm
# Nyle  natutals Petroleum Jelly (With Antiseptic Properties) with Apple & Neem Oil
# Parachute SkinPure Beauty Olive Oil 100ml (15ml Petroleum Jelly Free)
# Vaseline Blue Seal Men Cooling Petroleum Jelly
# Vaseline Blue Seal Men Fresh Petroleum Jelly
# Vaseline Pure Petroleum Jelly
# Scraping for keyword: hairoil
# Parachute Advansed Onion Enriched Coconut Hair Growth Oil
# Hawaa Hair Fall Avenger Oil
# Maya All Natural Scalp & Hair Oil  100 ml
# SESA Herbal Hair Oil
# SESA Regain Hair Oil ( 2 Step Hair Growth Kit , Clinically Proven)
# Sesa Onion Herbal hair oil
# Aarong Earth Hair Oil With Black Seed & Sesame Extract
# Pantene Pro-V Hair Oil Replacement Leave On Cream Super Food
# Parachute Hair Oil Anti Hairfall Oil Extra Care (Root Applier)
# Vatika Cactus Enriched Hair Oil
# Lucy Gold Oilve Hair Oil
# Buy Parachute Hair Oil Advansed Aloe Vera Enriched Coconut 250Ml + Parachute Naturale Shampoo Damage Repair 170Ml Get One Skinpure Aloe Vera Gel 50G Free
# Emami 7 Oils in One Non Sticky Hair Oil
# Vatika Naturals Almond Enriched Hair Oil
# Buy Parachute Hair Oil Advansed Aloe Vera Enriched Coconut 250Ml + Parachute Naturale Shampoo Anti Hair Fall 170Ml Get Skinpure Aloe Vera Gel 50G Free
# Total SKUs found: 1885
# Elapsed time to report (mins): 7.84

# %%
# Daraz SoS

# import
import pandas as pd
import duckdb
from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup
from googleapiclient.discovery import build
from google.oauth2 import service_account
import time

# accumulators
start_time = time.time()
df_acc = pd.DataFrame()

# particulars
keywords = ['conditioner', 'handwash', 'bodywash', 'facewash', 'lotion', 'cream', 'toothpaste', 'dishwash', 'toilet clean', 'soup', 'shampoo', 'health drink', 'detergent', 'moisturizer', 'soap', 'petroleum jelly', 'hair oil', 'germ kill']
brands = ['Boost Health', 'Boost Drink', 'Boost Jar', 'Clear Shampoo', 'Simple Fac', 'Simple Mask', 'Pepsodent', 'Brylcreem', 'Bru Coffee', 'St. Ives', 'St.Ives', 'Horlicks', 'Sunsilk', 'Sun Silk', 'Lux', 'Ponds', "Pond's", 'Closeup', 'Close Up', 'Cif', 'Dove', 'Maltova', 'Domex', 'Clinic Plus', 'Tresemme', 'Tresemmé', 'GlucoMax', 'Knorr', 'Glow Lovely', 'Fair Lovely', 'Glow Handsome', 'Wheel Wash', 'Axe Body', 'Pureit', 'Lifebuoy', 'Surf Excel', 'Vaseline', 'Vim', 'Rin']

# subsequence
def is_subseq(x, y):
    it = iter(y)
    return all(any(c == ch for c in it) for ch in x)

# preference
options = webdriver.ChromeOptions()
options.add_argument('ignore-certificate-errors')

# open window
driver = webdriver.Chrome(options=options)
driver.maximize_window()
driver.get('https://www.daraz.com.bd/')

# keyword
for k in keywords:
    print("Scraping for keyword: " + k)
    elem = driver.find_element(By.ID, "q")
    elem.send_keys(Keys.CONTROL + "a")
    elem.send_keys(Keys.DELETE)
    elem.send_keys(k + "\n")

    # initialize
    pg = 1
    pos = 0
    new_skus = set()
    while(1):

        # scroll
        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            time.sleep(5)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height: break
            last_height = new_height

        # soup
        soup_init = BeautifulSoup(driver.page_source, "html.parser")
        soup = soup_init.find_all("div", attrs={"class": "gridItem--Yd0sa"})

        # scrape
        sku = []
        current_price = []
        original_price = []
        offer = []
        rating = []
        reviews = []
        in_mall = []
        in_mart = []
        position = []
        sku_count = len(soup)
        for i in range(0, sku_count):            
            
            # SKU
            try: val = soup[i].find("div", attrs={"id": "id-title"}).get_text()
            except: val = None
            sku.append(val)
            # current price
            try: val = soup[i].find("span", attrs={"class": "currency--GVKjl"}).get_text()
            except: val = None
            current_price.append(val)
            # original price
            try: val = soup[i].find("del", attrs={"class": "currency--GVKjl"}).get_text()[2:]
            except: val = None
            original_price.append(val)
            # offer
            try: val = soup[i].find("div", attrs={"class": "voucher-wrapper--vCNzH"}).get_text()
            except: val = None
            offer.append(val)
            # rating    
            try: val = soup[i].find("span", attrs={"class": "ratig-num--KNake rating--pwPrV"}).get_text()
            except: val = None
            rating.append(val)
            # reviews
            try: val = soup[i].find("span", attrs={"class": "rating__review--ygkUy"}).get_text()[1:-1]
            except: val = None
            reviews.append(val)
            # mall
            in_mall.append(1)
            try: soup[i].find("i", attrs={"style": "background-image: url(&quot;https://img.alicdn.com/imgextra/i2/O1CN01m9OC6a1UK86X51Dcq_!!6000000002498-2-tps-108-54.png&quot;); width: 32px; height: 16px; vertical-align: text-bottom;"})["class"]
            except: in_mall[i] = 0
            # mart
            in_mart.append(1)
            try: soup[i].find("i", attrs={"style": "background-image: url(&quot;https://img.alicdn.com/imgextra/i1/O1CN01gS7Ros1VI7zYtUDwQ_!!6000000002629-2-tps-64-32.png&quot;); width: 32px; height: 16px; vertical-align: text-bottom;"})["class"]
            except: in_mart[i] = 0
            # position
            pos = pos + 1
            position.append(pos)
            
        # novelty
        skus_before = len(new_skus)
        for s in sku: 
            if is_subseq(k.replace(' ', ''), s.lower()): 
                new_skus.add(s)
        if len(new_skus) == skus_before: break

        # accumulate 
        df = pd.DataFrame()
        df['sku'] = sku
        df['current_price'] = current_price
        df['original_price'] = original_price
        df['offer'] = offer
        df['rating'] = rating
        df['reviews'] = reviews
        df['in_mall'] = in_mall
        df['in_mart'] = in_mart
        df['keyword'] = k
        df['relevance'] = ['relevant' if is_subseq(k.replace(' ', ''), s.lower()) else 'irrelevant' for s in sku]
        df['pg_no'] = pg
        df['position'] = position

        # Unilever
        if_ubl = []
        skus = len(sku)
        for i in range(0, skus):
            if_ubl.append(None)
            for b in brands:
                bb = b.split()
                if len(bb) == 1: bb.append('')
                if bb[0].lower() + ' ' in sku[i].lower() and bb[1].lower() in sku[i].lower(): if_ubl[i] = b
        df['brand_unilever'] = if_ubl

        # record
        df['report_time'] = time.strftime('%d-%b-%y, %I:%M %p')
        df_acc = df_acc._append(df).fillna('')

        # next page
        elem = driver.find_element(By.CLASS_NAME, "ant-pagination-next")
        ActionChains(driver).move_to_element(elem).click().perform()

        # limit
        pg = pg + 1
        if pg == 16: break
    
# close window
driver.close()

# SoS
qry = '''
select
    keyword, 
    count(1) results, 
    count(case when relevance='relevant' then 1 else null end) relevant_results, 
    count(case when relevance='relevant' and brand_unilever!='' then 1 else null end) relevant_results_ubl,
    round(count(case when relevance='relevant' and brand_unilever!='' then 1 else null end)*1.00/count(case when relevance='relevant' then 1 else null end), 4) ubl_sos, 
    count(case when relevance='relevant' and brand_unilever!='' and position<11 then 1 else null end) ubl_sos_top10,
    max(report_time) report_time
from df_acc
group by 1
'''
sos_df = duckdb.query(qry).df().fillna('')

# credentials
SERVICE_ACCOUNT_FILE = 'read-write-to-gsheet-apis-1-04f16c652b1e.json'
SAMPLE_SPREADSHEET_ID = '1gkLRp59RyRw4UFds0-nNQhhWOaS4VFxtJ_Hgwg2x2A0'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

# APIs
creds = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
service = build('sheets', 'v4', credentials=creds)
sheet = service.spreadsheets()

# update
sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID, range='Daraz SoS').execute()
sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Daraz SoS!A1", valueInputOption='USER_ENTERED', body={'values': [df_acc.columns.values.tolist()] + df_acc.values.tolist()}).execute()
sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Daraz SoS!P1", valueInputOption='USER_ENTERED', body={'values': [sos_df.columns.values.tolist()] + sos_df.values.tolist()}).execute()

# stats
# display(df_acc.head(5))
print("Total SKUs found: " + str(df_acc.shape[0]))
elapsed_time = time.time() - start_time
print("Elapsed time to report (mins): " + str(round(elapsed_time / 60.00, 2)))
# Out:
# Scraping for keyword: conditioner
# Scraping for keyword: handwash
# Scraping for keyword: bodywash
# Scraping for keyword: facewash
# Scraping for keyword: lotion
# Scraping for keyword: cream
# Scraping for keyword: toothpaste
# Scraping for keyword: dishwash
# Scraping for keyword: toilet clean
# Scraping for keyword: soup
# Scraping for keyword: shampoo
# Scraping for keyword: health drink
# Scraping for keyword: detergent
# Scraping for keyword: moisturizer
# Scraping for keyword: soap
# Scraping for keyword: petroleum jelly
# Scraping for keyword: hair oil
# Scraping for keyword: germ kill
# Total SKUs found: 8301
# Elapsed time to report (mins): 23.96
